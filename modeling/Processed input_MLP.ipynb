# %%
import pandas as pd
import numpy as np
import random
import os
import time
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split

from numpy import hstack, vstack
import itertools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from itertools import product

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

from torch.utils.data import DataLoader, TensorDataset

import warnings
warnings.filterwarnings(action='ignore')

# %%
def find_directory(foldername, filename = None, back_num = 0):
    cur = os.getcwd()
    for i in range(back_num):
        cur = os.path.abspath(os.path.join(cur, os.pardir))
    for folder in foldername:
        cur = os.path.join(cur, folder)
    if not os.path.exists(cur):
        os.makedirs(cur)
        print(f'{cur} created')
    if filename != None:
        cur = os.path.join(cur, filename)
    return cur

os.getcwd()
# Out:
# 'c:\\Users\\dkstj\\Desktop\\연구\\현대차 3차\\Rapid_fin\\deep learning modeling'

# %%
csv_add = find_directory(foldername = [], filename = 'SOC_Point_Data.csv')
dat = pd.read_csv(csv_add, index_col = (0,1,2,3,4))

# %%
def Get_Data(dat) :
    
    RPT_MODE = "0.1C"
    SOC_Range = [9,10,11,12]

    Time_Range = range(6, 15, 2)
    SOC_Range = [str(i) for i in SOC_Range]
    

    Data = dat

    X = Data.loc[RPT_MODE, "0" : "16"]
    Y = Data.loc[RPT_MODE, ["SOH", "Next_SOH", "Ratio_SOH", "Ratio_CYC"]].groupby(level = ["Next", "Path", "Number"]).mean()
    
    y = pd.Series(Y["Next_SOH"] - Y["SOH"], name = "Delta_SOH")
    
    Y = pd.concat([Y, y], axis = 1)

    X_seek = X.loc[X.index.get_level_values("Time").isin(Time_Range), SOC_Range]


    X_std = X_seek.groupby(level = ["Next", "Path", "Number"]).std()
    
    return X_std, Y

# %%
def Even_Split(X, y, test_size, rs) :

    X_M = X.xs(key = 'M', level = 'Next', drop_level = False)
    X_D = X.xs(key = 'D', level = 'Next', drop_level = False)
    X_H = X.xs(key = 'H', level = 'Next', drop_level = False)
    
    XX = {"M" : X_M, "D" : X_D, "H" : X_H}
    
    y_M = y.xs(key = 'M', level = 'Next', drop_level = False)
    y_D = y.xs(key = 'D', level = 'Next', drop_level = False)
    y_H = y.xs(key = 'H', level = 'Next', drop_level = False)
    
    yy = {"M" : y_M, "D" : y_D, "H" : y_H}
    
    
    XXX = {"M" : [], "D" : [], "H" : []}
    
    yyy = {"M" : [], "D" : [], "H" : []}
    
    
    for n in ["M", "D", "H"] :
        for path in range(1,5) :
            X_path = XX[n].loc[XX[n].index.get_level_values(level = 'Path').str.len() == path]
            y_path = yy[n].loc[yy[n].index.get_level_values(level = 'Path').str.len() == path]
            
            XXX[n].append(X_path)
            yyy[n].append(y_path)
            
            
    XX_tn = {"M" : [], "D" : [], "H" : []}
    XX_te = {"M" : [], "D" : [], "H" : []}
    
    yy_tn = {"M" : [], "D" : [], "H" : []}
    yy_te = {"M" : [], "D" : [], "H" : []}
        
    for n in ["M", "D", "H"] :
        for path in range(1,5) :
            X_temp = XXX[n][path-1]
            y_temp = yyy[n][path-1]
            
            X_tn, X_te, y_tn, y_te = train_test_split(X_temp, y_temp, test_size = test_size, random_state = rs)
            
            XX_tn[n].append(X_tn)
            XX_te[n].append(X_te)
            yy_tn[n].append(y_tn)
            yy_te[n].append(y_te)
                  
    for n in ["M", "D", "H"] :
        XX_tn[n] = pd.concat(XX_tn[n])
        XX_te[n] = pd.concat(XX_te[n])
        yy_tn[n] = pd.concat(yy_tn[n])
        yy_te[n] = pd.concat(yy_te[n])
        
        
    X_tn = pd.concat(XX_tn.values())
    X_te = pd.concat(XX_te.values())
    
    y_tn = pd.concat(yy_tn.values())
    y_te = pd.concat(yy_te.values())
    
    return X_tn, X_te, y_tn, y_te

# %%
def get_next_tensor(index_list):
    next_mapping = {'M': 0, 'D': 1, 'H': 2}
    next_index = [next_mapping[idx[0]] for idx in index_list] 
    next_tensor = torch.tensor(next_index)
    one_hot = torch.nn.functional.one_hot(next_tensor, num_classes=3).float()
    return one_hot

# %%
def setRandomSeed(random_seed=0):
    os.environ['PYTHONHASHSEED'] = str(random_seed)
    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(random_seed)
    random.seed(random_seed)

# %%
class MLP(nn.Module):
    def __init__(self, hidden_dim=64, num_layers=2, next_dim = 3):
        super(MLP, self).__init__()
        layers = []

        input_dim = 4 + next_dim
        output_dim = 1

        layers.append(nn.Linear(input_dim, hidden_dim))
        layers.append(nn.ReLU())

        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(nn.ReLU())

        layers.append(nn.Linear(hidden_dim, output_dim))

        self.model = nn.Sequential(*layers)

    def forward(self, x, onehot):
        x_concat = torch.cat([x, onehot], dim=1)
        return self.model(x_concat)

class MAPELoss(nn.Module):
    def __init__(self, epsilon=1e-7):
        super(MAPELoss, self).__init__()
        self.epsilon = epsilon

    def forward(self, y_pred, y_true):
        return torch.mean(torch.abs((y_true - y_pred) / (y_true + self.epsilon))) * 100

# %%
class Trainer:
    def __init__(self, model, lr=1e-3, weight_decay=0, epoch=1000, patience=50, random_seed = 0):
        self.random_seed = random_seed
        #setRandomSeed(self.random_seed)
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.model = model.to(self.device)
        self.criterion = nn.MSELoss()
        self.cri2 = MAPELoss()
        self.optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.StepLR(self.optimizer, step_size=200, gamma=0.8)
        self.epoch = epoch
        self.patience = patience

        self.train_loss = []
        self.test_loss = []
        self.val_loss = []

    def train(self, train_loader, test_loader=None, val_loader=None):
        best_val_loss = float('inf')
        best_model_state = None
        epochs_no_improve = 0

        for ep in range(1, self.epoch + 1):
            self.model.train()
            for x_batch, onehot, y_batch in train_loader:
                x_batch, onehot, y_batch = x_batch.to(self.device), onehot.to(self.device), y_batch.to(self.device)

                self.optimizer.zero_grad()
                outputs = self.model(x_batch, onehot)
                loss = self.cri2(outputs, y_batch)
                loss.backward()
                self.optimizer.step()

            self.scheduler.step()

            avg_train_loss = self.evaluate(train_loader)
            test_loss = self.evaluate(test_loader) if test_loader else None
            val_loss = self.evaluate(val_loader) if val_loader else None

            self.train_loss.append(avg_train_loss)
            self.test_loss.append(test_loss)
            self.val_loss.append(val_loss)

            if val_loader:
                if val_loss < best_val_loss - 1e-4:
                    best_val_loss = val_loss
                    best_model_state = self.model.state_dict()
                    epochs_no_improve = 0
                else:
                    epochs_no_improve += 1
                    if epochs_no_improve >= self.patience:
                        print(f"Early stopping at epoch {ep}")
                        break

        if best_model_state:
            self.model.load_state_dict(best_model_state)

    def evaluate(self, data_loader):
        if data_loader is None:
            return None
        self.model.eval()
        total_loss = 0
        with torch.no_grad():
            for x_batch, onehot, y_batch in data_loader:
                x_batch, onehot, y_batch = x_batch.to(self.device), onehot.to(self.device), y_batch.to(self.device)
                outputs = self.model(x_batch, onehot)
                loss = self.cri2(outputs, y_batch)
                total_loss += loss.item()
        return total_loss / len(data_loader)

    def predict(self, x, onehot):
        self.model.eval()
        with torch.no_grad():
            x = x.to(self.device)
            onehot = onehot.to(self.device)
            return self.model(x, onehot)

# %%
def plot_results(info, train_loader, val_loader, test_loader, plot = True):
    rs, hid, nl, lr = info
    
    y_true_train = []
    y_pred_train = []
    
    y_true_val = []
    y_pred_val = []
    
    y_true_test = []
    y_pred_test = []

    y_true_test_M = []
    y_pred_test_M = []

    y_true_test_D = []
    y_pred_test_D = []

    y_true_test_H = []
    y_pred_test_H = []
    
    for x_batch, onehot, y_batch in train_loader:
        preds = trainer.predict(x_batch, onehot)
        y_true_train.append(y_batch)
        y_pred_train.append(preds.cpu())
    
    for x_batch, onehot, y_batch in val_loader:
        preds = trainer.predict(x_batch, onehot)
        y_true_val.append(y_batch)
        y_pred_val.append(preds.cpu())
    
    for x_batch, onehot, y_batch in test_loader:
        preds = trainer.predict(x_batch, onehot)
        y_true_test.append(y_batch)
        y_pred_test.append(preds.cpu())
    
        onehot_np = onehot.cpu().numpy()
        y_true_np = y_batch.cpu().numpy()
        y_pred_np = preds.cpu().numpy()
    
        for i in range(len(onehot_np)):
            if np.array_equal(onehot_np[i], [1, 0, 0]):  # 'M'
                y_true_test_M.append(y_true_np[i])
                y_pred_test_M.append(y_pred_np[i])
            elif np.array_equal(onehot_np[i], [0, 1, 0]):  # 'D'
                y_true_test_D.append(y_true_np[i])
                y_pred_test_D.append(y_pred_np[i])
            elif np.array_equal(onehot_np[i], [0, 0, 1]):  # 'H'
                y_true_test_H.append(y_true_np[i])
                y_pred_test_H.append(y_pred_np[i])
    
    y_true_train = torch.cat(y_true_train).numpy()
    y_pred_train = torch.cat(y_pred_train).numpy()
    
    y_true_val = torch.cat(y_true_val).numpy()
    y_pred_val = torch.cat(y_pred_val).numpy()
    
    y_true_test = torch.cat(y_true_test).numpy()
    y_pred_test = torch.cat(y_pred_test).numpy()

    y_true_test_M = np.array(y_true_test_M)
    y_pred_test_M = np.array(y_pred_test_M)
    
    y_true_test_D = np.array(y_true_test_D)
    y_pred_test_D = np.array(y_pred_test_D)
    
    y_true_test_H = np.array(y_true_test_H)
    y_pred_test_H = np.array(y_pred_test_H)
    
    mape_M = mean_absolute_percentage_error(y_true_test_M, y_pred_test_M) * 100 if len(y_true_test_M) > 0 else np.nan
    mape_D = mean_absolute_percentage_error(y_true_test_D, y_pred_test_D) * 100 if len(y_true_test_D) > 0 else np.nan
    mape_H = mean_absolute_percentage_error(y_true_test_H, y_pred_test_H) * 100 if len(y_true_test_H) > 0 else np.nan
    
    train_mape = mean_absolute_percentage_error(y_true_train, y_pred_train) * 100
    val_mape = mean_absolute_percentage_error(y_true_val, y_pred_val) * 100
    test_mape = mean_absolute_percentage_error(y_true_test, y_pred_test) * 100
    print(f"Rs: {rs}, hid: {hid}, {nl} layers, lr: {lr}\n Train MAPE: {train_mape:.2f}%, Val MAPE: {val_mape:.2f}%, Test MAPE: {test_mape:.2f}%")
    print(f"Test MAPE by 'Next': M: {mape_M:.2f}%, D: {mape_D:.2f}%, H: {mape_H:.2f}%")
    if plot == True:
        _ = plt.figure()
        _ = plt.scatter(y_true_train, y_pred_train, label = 'Train')
        _ = plt.scatter(y_true_val, y_pred_val, label = 'Val')
        _ = plt.scatter(y_true_test, y_pred_test, label = 'Test')
        min_val = min(y_true_train.min(), y_true_test.min())
        max_val = max(y_true_train.max(), y_true_test.max())
        _ = plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Ideal line')
        _ = plt.xlabel('True SOH')
        _ = plt.ylabel('Predicted SOH')
        _ = plt.legend()
        _ = plt.title(f'Random state: {rs}, hid: {hid}, {nl} layer, lr: {lr}')
    return train_mape, val_mape, test_mape, mape_M, mape_D, mape_H

def plot_loss(info, train_loss, val_loss, test_loss):
    rs, hid, nl, lr = info
    _ = plt.figure()
    _ = plt.plot(train_loss, label = 'Train loss')
    _ = plt.plot(val_loss, label = 'Val loss')
    _ = plt.plot(test_loss, label = 'Test loss')
    _ = plt.ylim([0, 2])
    _ = plt.xlabel('Epoch')
    _ = plt.ylabel('Loss')
    _ = plt.legend()
    _ = plt.title(f'Random state: {rs}, hid: {hid}, {nl} layers, lr: {lr}')

# %%
random_states = [100, 120, 140, 160, 180]
bs = 12
ep = 1000
hids = [8, 16, 32]
layers = [2, 3, 4, 5, 6]
lrs = [1e-3, 1e-4]

results_df = pd.DataFrame(columns = ['rs', 'hid', 'nl', 'lr', 'Train MAPE', 'Val MAPE', 'Test MAPE', 'Next M MAPE', 'Next D MAPE', 'Next H MAPE'])

X, y = Get_Data(dat)

for rs, hid, nl, lr in product(random_states, hids, layers, lrs):
    setRandomSeed(rs)

    X_tn, X_te, y_tn, y_te = Even_Split(X, y, 1/3, rs)
    X_tr, X_va, y_tr, y_va = Even_Split(X_tn, y_tn, 1/6, rs)

    next_map = {'M': 0, 'D': 1, 'H': 2}
    get_next = lambda idx: torch.nn.functional.one_hot(torch.tensor([next_map[i] for i in idx.get_level_values("Next")]), num_classes=3).float()

    std_scaler = StandardScaler()
    X_tr_std = std_scaler.fit_transform(X_tr)
    X_val_std = std_scaler.transform(X_va)
    X_te_std = std_scaler.transform(X_te)
    
    X_train = torch.Tensor(X_tr_std)
    X_val = torch.Tensor(X_val_std)
    X_test = torch.Tensor(X_te_std)
    
    y_train = torch.Tensor(y_tr["Next_SOH"].values).unsqueeze(1)
    y_val = torch.Tensor(y_va["Next_SOH"].values).unsqueeze(1)
    y_test = torch.Tensor(y_te["Next_SOH"].values).unsqueeze(1)

    next_train = get_next(X_tr.index)
    next_val = get_next(X_va.index)
    next_test = get_next(X_te.index)

    train_loader = DataLoader(TensorDataset(X_train, next_train, y_train), batch_size=bs, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val, next_val, y_val), batch_size=bs, shuffle = False)
    test_loader = DataLoader(TensorDataset(X_test, next_test, y_test), batch_size=bs, shuffle = False)
    
    model = MLP(hidden_dim=hid, num_layers=nl)
    trainer = Trainer(model, lr=lr, epoch = ep, random_seed = rs)
    
    trainer.train(train_loader, val_loader, test_loader)

    info = [rs, hid, nl, lr]
    results = plot_results(info, train_loader, val_loader, test_loader, plot = False)

    temp_df = pd.DataFrame(info+list(results)).T
    temp_df.columns = ['rs', 'hid', 'nl', 'lr', 'Train MAPE', 'Val MAPE', 'Test MAPE', 'Next M MAPE', 'Next D MAPE', 'Next H MAPE']
    results_df = pd.concat([results_df, temp_df])
# Out:
# Early stopping at epoch 267
# Rs: 100, hid: 8, 2 layers, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 0.86%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.08%, D: 1.11%, H: 1.13%
# Rs: 100, hid: 8, 2 layers, lr: 0.0001
#  Train MAPE: 0.90%, Val MAPE: 1.14%, Test MAPE: 1.45%
# Test MAPE by 'Next': M: 1.08%, D: 0.97%, H: 2.31%
# Early stopping at epoch 186
# Rs: 100, hid: 8, 3 layers, lr: 0.001
#  Train MAPE: 0.73%, Val MAPE: 0.75%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.90%, D: 0.89%, H: 0.80%
# Rs: 100, hid: 8, 3 layers, lr: 0.0001
#  Train MAPE: 0.78%, Val MAPE: 0.85%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.01%, D: 0.81%, H: 0.99%
# Early stopping at epoch 166
# Rs: 100, hid: 8, 4 layers, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.83%, Test MAPE: 0.82%
# Test MAPE by 'Next': M: 0.90%, D: 0.81%, H: 0.73%
# Rs: 100, hid: 8, 4 layers, lr: 0.0001
#  Train MAPE: 0.78%, Val MAPE: 0.84%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.90%, D: 0.89%, H: 0.90%
# Early stopping at epoch 131
# Rs: 100, hid: 8, 5 layers, lr: 0.001
#  Train MAPE: 0.92%, Val MAPE: 1.13%, Test MAPE: 1.25%
# Test MAPE by 'Next': M: 1.22%, D: 1.08%, H: 1.46%
# Rs: 100, hid: 8, 5 layers, lr: 0.0001
#  Train MAPE: 0.74%, Val MAPE: 1.00%, Test MAPE: 1.02%
# Test MAPE by 'Next': M: 1.09%, D: 0.75%, H: 1.21%
# Early stopping at epoch 168
# Rs: 100, hid: 8, 6 layers, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# Early stopping at epoch 772
# Rs: 100, hid: 8, 6 layers, lr: 0.0001
#  Train MAPE: 1.82%, Val MAPE: 1.89%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.95%, D: 1.79%, H: 1.73%
# Early stopping at epoch 227
# Rs: 100, hid: 16, 2 layers, lr: 0.001
#  Train MAPE: 0.71%, Val MAPE: 0.79%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.26%, D: 0.85%, H: 1.09%
# Early stopping at epoch 793
# Rs: 100, hid: 16, 2 layers, lr: 0.0001
#  Train MAPE: 0.77%, Val MAPE: 1.05%, Test MAPE: 1.15%
# Test MAPE by 'Next': M: 1.31%, D: 1.01%, H: 1.13%
# Early stopping at epoch 112
# Rs: 100, hid: 16, 3 layers, lr: 0.001
#  Train MAPE: 0.78%, Val MAPE: 0.72%, Test MAPE: 1.07%
# Test MAPE by 'Next': M: 1.17%, D: 0.82%, H: 1.21%
# Early stopping at epoch 578
# Rs: 100, hid: 16, 3 layers, lr: 0.0001
#  Train MAPE: 0.66%, Val MAPE: 0.98%, Test MAPE: 1.17%
# Test MAPE by 'Next': M: 1.14%, D: 0.93%, H: 1.46%
# Early stopping at epoch 129
# Rs: 100, hid: 16, 4 layers, lr: 0.001
#  Train MAPE: 0.70%, Val MAPE: 0.90%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.14%, D: 0.74%, H: 0.90%
# Early stopping at epoch 490
# Rs: 100, hid: 16, 4 layers, lr: 0.0001
#  Train MAPE: 0.74%, Val MAPE: 1.02%, Test MAPE: 1.10%
# Test MAPE by 'Next': M: 1.16%, D: 0.82%, H: 1.31%
# Early stopping at epoch 127
# Rs: 100, hid: 16, 5 layers, lr: 0.001
#  Train MAPE: 0.65%, Val MAPE: 0.83%, Test MAPE: 0.84%
# Test MAPE by 'Next': M: 0.96%, D: 0.81%, H: 0.74%
# Early stopping at epoch 510
# Rs: 100, hid: 16, 5 layers, lr: 0.0001
#  Train MAPE: 0.67%, Val MAPE: 0.89%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.96%, D: 0.82%, H: 0.82%
# Early stopping at epoch 178
# Rs: 100, hid: 16, 6 layers, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.92%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.08%, D: 1.04%, H: 0.84%
# Rs: 100, hid: 16, 6 layers, lr: 0.0001
#  Train MAPE: 0.62%, Val MAPE: 0.92%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.99%, D: 0.80%, H: 0.94%
# Early stopping at epoch 236
# Rs: 100, hid: 32, 2 layers, lr: 0.001
#  Train MAPE: 0.57%, Val MAPE: 1.20%, Test MAPE: 1.12%
# Test MAPE by 'Next': M: 1.40%, D: 1.02%, H: 0.95%
# Early stopping at epoch 513
# Rs: 100, hid: 32, 2 layers, lr: 0.0001
#  Train MAPE: 0.61%, Val MAPE: 1.51%, Test MAPE: 1.20%
# Test MAPE by 'Next': M: 1.45%, D: 0.90%, H: 1.24%
# Early stopping at epoch 186
# Rs: 100, hid: 32, 3 layers, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.97%, Test MAPE: 1.41%
# Test MAPE by 'Next': M: 1.52%, D: 1.16%, H: 1.54%
# Early stopping at epoch 709
# Rs: 100, hid: 32, 3 layers, lr: 0.0001
#  Train MAPE: 0.67%, Val MAPE: 1.40%, Test MAPE: 1.59%
# Test MAPE by 'Next': M: 1.63%, D: 1.43%, H: 1.70%
# Early stopping at epoch 140
# Rs: 100, hid: 32, 4 layers, lr: 0.001
#  Train MAPE: 0.58%, Val MAPE: 0.97%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.18%, D: 0.87%, H: 1.06%
# Early stopping at epoch 563
# Rs: 100, hid: 32, 4 layers, lr: 0.0001
#  Train MAPE: 0.52%, Val MAPE: 0.89%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.12%, D: 0.94%, H: 1.08%
# Early stopping at epoch 155
# Rs: 100, hid: 32, 5 layers, lr: 0.001
#  Train MAPE: 0.65%, Val MAPE: 1.19%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.32%, D: 0.81%, H: 1.03%
# Early stopping at epoch 421
# Rs: 100, hid: 32, 5 layers, lr: 0.0001
#  Train MAPE: 0.62%, Val MAPE: 0.96%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.20%, D: 0.85%, H: 0.92%
# Early stopping at epoch 89
# Rs: 100, hid: 32, 6 layers, lr: 0.001
#  Train MAPE: 0.57%, Val MAPE: 0.90%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.18%, D: 0.76%, H: 0.77%
# Early stopping at epoch 266
# Rs: 100, hid: 32, 6 layers, lr: 0.0001
#  Train MAPE: 0.72%, Val MAPE: 0.91%, Test MAPE: 1.02%
# Test MAPE by 'Next': M: 1.11%, D: 0.90%, H: 1.05%
# Early stopping at epoch 282
# Rs: 120, hid: 8, 2 layers, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 0.89%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 1.16%, D: 0.75%, H: 0.76%
# Rs: 120, hid: 8, 2 layers, lr: 0.0001
#  Train MAPE: 0.91%, Val MAPE: 0.83%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.40%, D: 0.93%, H: 0.81%
# Early stopping at epoch 160
# Rs: 120, hid: 8, 3 layers, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.86%, Test MAPE: 0.71%
# Test MAPE by 'Next': M: 0.78%, D: 0.87%, H: 0.48%
# Rs: 120, hid: 8, 3 layers, lr: 0.0001
#  Train MAPE: 0.88%, Val MAPE: 0.85%, Test MAPE: 0.73%
# Test MAPE by 'Next': M: 0.72%, D: 0.84%, H: 0.63%
# Early stopping at epoch 124
# Rs: 120, hid: 8, 4 layers, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.84%, Test MAPE: 0.75%
# Test MAPE by 'Next': M: 0.83%, D: 0.75%, H: 0.67%
# Early stopping at epoch 660
# Rs: 120, hid: 8, 4 layers, lr: 0.0001
#  Train MAPE: 0.91%, Val MAPE: 0.92%, Test MAPE: 0.73%
# Test MAPE by 'Next': M: 0.78%, D: 0.70%, H: 0.71%
# Early stopping at epoch 128
# Rs: 120, hid: 8, 5 layers, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.76%, Test MAPE: 0.69%
# Test MAPE by 'Next': M: 0.82%, D: 0.65%, H: 0.60%
# Early stopping at epoch 528
# Rs: 120, hid: 8, 5 layers, lr: 0.0001
#  Train MAPE: 0.86%, Val MAPE: 0.84%, Test MAPE: 0.68%
# Test MAPE by 'Next': M: 0.78%, D: 0.65%, H: 0.62%
# Early stopping at epoch 162
# Rs: 120, hid: 8, 6 layers, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.76%, Test MAPE: 0.65%
# Test MAPE by 'Next': M: 0.79%, D: 0.64%, H: 0.51%
# Early stopping at epoch 862
# Rs: 120, hid: 8, 6 layers, lr: 0.0001
#  Train MAPE: 0.90%, Val MAPE: 0.85%, Test MAPE: 0.70%
# Test MAPE by 'Next': M: 0.74%, D: 0.64%, H: 0.73%
# Early stopping at epoch 175
# Rs: 120, hid: 16, 2 layers, lr: 0.001
#  Train MAPE: 1.03%, Val MAPE: 1.09%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.02%, D: 1.06%, H: 1.25%
# Rs: 120, hid: 16, 2 layers, lr: 0.0001
#  Train MAPE: 0.87%, Val MAPE: 0.97%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.17%, D: 0.76%, H: 1.12%
# Early stopping at epoch 152
# Rs: 120, hid: 16, 3 layers, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 1.03%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.30%, D: 0.86%, H: 1.04%
# Early stopping at epoch 612
# Rs: 120, hid: 16, 3 layers, lr: 0.0001
#  Train MAPE: 0.74%, Val MAPE: 0.84%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.84%, D: 0.81%, H: 0.99%
# Early stopping at epoch 184
# Rs: 120, hid: 16, 4 layers, lr: 0.001
#  Train MAPE: 0.99%, Val MAPE: 1.02%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.08%, D: 0.86%, H: 0.92%
# Early stopping at epoch 173
# Rs: 120, hid: 16, 4 layers, lr: 0.0001
#  Train MAPE: 1.05%, Val MAPE: 1.16%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.18%, D: 1.17%, H: 0.99%
# Early stopping at epoch 186
# Rs: 120, hid: 16, 5 layers, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 0.85%, Test MAPE: 0.82%
# Test MAPE by 'Next': M: 0.93%, D: 0.74%, H: 0.80%
# Early stopping at epoch 587
# Rs: 120, hid: 16, 5 layers, lr: 0.0001
#  Train MAPE: 0.77%, Val MAPE: 0.90%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 1.04%, D: 0.82%, H: 0.76%
# Early stopping at epoch 138
# Rs: 120, hid: 16, 6 layers, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 0.85%, Test MAPE: 0.76%
# Test MAPE by 'Next': M: 0.94%, D: 0.72%, H: 0.61%
# Early stopping at epoch 882
# Rs: 120, hid: 16, 6 layers, lr: 0.0001
#  Train MAPE: 0.79%, Val MAPE: 0.87%, Test MAPE: 0.74%
# Test MAPE by 'Next': M: 0.80%, D: 0.69%, H: 0.73%
# Early stopping at epoch 161
# Rs: 120, hid: 32, 2 layers, lr: 0.001
#  Train MAPE: 1.07%, Val MAPE: 1.17%, Test MAPE: 1.16%
# Test MAPE by 'Next': M: 1.05%, D: 1.28%, H: 1.16%
# Early stopping at epoch 520
# Rs: 120, hid: 32, 2 layers, lr: 0.0001
#  Train MAPE: 0.69%, Val MAPE: 1.09%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 0.98%, D: 0.93%, H: 0.94%
# Early stopping at epoch 186
# Rs: 120, hid: 32, 3 layers, lr: 0.001
#  Train MAPE: 1.02%, Val MAPE: 1.15%, Test MAPE: 1.08%
# Test MAPE by 'Next': M: 1.09%, D: 1.22%, H: 0.93%
# Early stopping at epoch 213
# Rs: 120, hid: 32, 3 layers, lr: 0.0001
#  Train MAPE: 0.78%, Val MAPE: 0.92%, Test MAPE: 0.97%
# Test MAPE by 'Next': M: 1.18%, D: 0.96%, H: 0.78%
# Early stopping at epoch 150
# Rs: 120, hid: 32, 4 layers, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 1.14%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.89%, D: 1.08%, H: 0.63%
# Early stopping at epoch 264
# Rs: 120, hid: 32, 4 layers, lr: 0.0001
#  Train MAPE: 0.69%, Val MAPE: 0.83%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.96%, D: 0.76%, H: 0.86%
# Early stopping at epoch 133
# Rs: 120, hid: 32, 5 layers, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 0.92%, Test MAPE: 0.81%
# Test MAPE by 'Next': M: 0.87%, D: 0.81%, H: 0.74%
# Early stopping at epoch 273
# Rs: 120, hid: 32, 5 layers, lr: 0.0001
#  Train MAPE: 0.70%, Val MAPE: 0.85%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.97%, D: 0.76%, H: 0.84%
# Early stopping at epoch 103
# Rs: 120, hid: 32, 6 layers, lr: 0.001
#  Train MAPE: 0.97%, Val MAPE: 0.94%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.07%, D: 0.63%, H: 1.17%
# Early stopping at epoch 279
# Rs: 120, hid: 32, 6 layers, lr: 0.0001
#  Train MAPE: 0.78%, Val MAPE: 0.82%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 1.01%, D: 0.78%, H: 0.89%
# Early stopping at epoch 340
# Rs: 140, hid: 8, 2 layers, lr: 0.001
#  Train MAPE: 0.68%, Val MAPE: 1.12%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.05%, D: 1.04%, H: 0.74%
# Early stopping at epoch 716
# Rs: 140, hid: 8, 2 layers, lr: 0.0001
#  Train MAPE: 0.93%, Val MAPE: 1.02%, Test MAPE: 1.19%
# Test MAPE by 'Next': M: 1.58%, D: 0.98%, H: 1.01%
# Early stopping at epoch 156
# Rs: 140, hid: 8, 3 layers, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.96%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 0.97%, D: 0.93%, H: 0.89%
# Rs: 140, hid: 8, 3 layers, lr: 0.0001
#  Train MAPE: 0.84%, Val MAPE: 1.05%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 0.98%, D: 0.96%, H: 0.81%
# Early stopping at epoch 173
# Rs: 140, hid: 8, 4 layers, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 1.17%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.05%, D: 1.10%, H: 0.97%
# Early stopping at epoch 710
# Rs: 140, hid: 8, 4 layers, lr: 0.0001
#  Train MAPE: 0.66%, Val MAPE: 1.11%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 1.03%, D: 0.98%, H: 0.69%
# Early stopping at epoch 156
# Rs: 140, hid: 8, 5 layers, lr: 0.001
#  Train MAPE: 0.70%, Val MAPE: 1.09%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 1.02%, D: 0.90%, H: 0.70%
# Early stopping at epoch 745
# Rs: 140, hid: 8, 5 layers, lr: 0.0001
#  Train MAPE: 0.75%, Val MAPE: 1.02%, Test MAPE: 0.84%
# Test MAPE by 'Next': M: 0.97%, D: 0.85%, H: 0.70%
# Early stopping at epoch 197
# Rs: 140, hid: 8, 6 layers, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 0.99%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.95%, D: 1.01%, H: 0.67%
# Early stopping at epoch 517
# Rs: 140, hid: 8, 6 layers, lr: 0.0001
#  Train MAPE: 0.78%, Val MAPE: 0.91%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.96%, D: 0.91%, H: 0.75%
# Early stopping at epoch 267
# Rs: 140, hid: 16, 2 layers, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 1.42%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.38%, D: 0.99%, H: 0.79%
# Early stopping at epoch 846
# Rs: 140, hid: 16, 2 layers, lr: 0.0001
#  Train MAPE: 0.69%, Val MAPE: 1.40%, Test MAPE: 1.08%
# Test MAPE by 'Next': M: 1.15%, D: 0.91%, H: 1.16%
# Early stopping at epoch 208
# Rs: 140, hid: 16, 3 layers, lr: 0.001
#  Train MAPE: 0.58%, Val MAPE: 1.19%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 1.02%, D: 0.86%, H: 0.76%
# Early stopping at epoch 685
# Rs: 140, hid: 16, 3 layers, lr: 0.0001
#  Train MAPE: 0.60%, Val MAPE: 1.17%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 1.01%, D: 0.94%, H: 0.67%
# Early stopping at epoch 225
# Rs: 140, hid: 16, 4 layers, lr: 0.001
#  Train MAPE: 0.64%, Val MAPE: 1.08%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.02%, D: 0.96%, H: 0.79%
# Early stopping at epoch 593
# Rs: 140, hid: 16, 4 layers, lr: 0.0001
#  Train MAPE: 0.77%, Val MAPE: 1.37%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.08%, D: 1.15%, H: 0.93%
# Early stopping at epoch 95
# Rs: 140, hid: 16, 5 layers, lr: 0.001
#  Train MAPE: 0.66%, Val MAPE: 1.00%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.97%, D: 0.83%, H: 0.79%
# Early stopping at epoch 481
# Rs: 140, hid: 16, 5 layers, lr: 0.0001
#  Train MAPE: 0.63%, Val MAPE: 0.89%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 1.03%, D: 0.95%, H: 0.69%
# Early stopping at epoch 150
# Rs: 140, hid: 16, 6 layers, lr: 0.001
#  Train MAPE: 0.68%, Val MAPE: 1.29%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 1.05%, D: 0.81%, H: 0.73%
# Early stopping at epoch 502
# Rs: 140, hid: 16, 6 layers, lr: 0.0001
#  Train MAPE: 0.76%, Val MAPE: 1.11%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.17%, D: 0.91%, H: 0.73%
# Early stopping at epoch 115
# Rs: 140, hid: 32, 2 layers, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 1.26%, Test MAPE: 1.28%
# Test MAPE by 'Next': M: 1.57%, D: 1.11%, H: 1.15%
# Early stopping at epoch 363
# Rs: 140, hid: 32, 2 layers, lr: 0.0001
#  Train MAPE: 0.64%, Val MAPE: 1.42%, Test MAPE: 1.19%
# Test MAPE by 'Next': M: 1.39%, D: 1.05%, H: 1.13%
# Early stopping at epoch 183
# Rs: 140, hid: 32, 3 layers, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 1.38%, Test MAPE: 1.13%
# Test MAPE by 'Next': M: 1.20%, D: 1.13%, H: 1.07%
# Early stopping at epoch 489
# Rs: 140, hid: 32, 3 layers, lr: 0.0001
#  Train MAPE: 0.60%, Val MAPE: 1.32%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.06%, D: 0.97%, H: 0.95%
# Early stopping at epoch 151
# Rs: 140, hid: 32, 4 layers, lr: 0.001
#  Train MAPE: 0.65%, Val MAPE: 1.39%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.16%, D: 0.99%, H: 0.87%
# Early stopping at epoch 234
# Rs: 140, hid: 32, 4 layers, lr: 0.0001
#  Train MAPE: 0.61%, Val MAPE: 1.39%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.09%, D: 0.99%, H: 1.06%
# Early stopping at epoch 173
# Rs: 140, hid: 32, 5 layers, lr: 0.001
#  Train MAPE: 0.58%, Val MAPE: 1.21%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 1.05%, D: 0.83%, H: 0.76%
# Early stopping at epoch 618
# Rs: 140, hid: 32, 5 layers, lr: 0.0001
#  Train MAPE: 0.60%, Val MAPE: 1.25%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.09%, D: 0.77%, H: 0.96%
# Early stopping at epoch 154
# Rs: 140, hid: 32, 6 layers, lr: 0.001
#  Train MAPE: 0.61%, Val MAPE: 0.94%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.92%, D: 0.90%, H: 0.75%
# Early stopping at epoch 390
# Rs: 140, hid: 32, 6 layers, lr: 0.0001
#  Train MAPE: 0.63%, Val MAPE: 1.06%, Test MAPE: 0.81%
# Test MAPE by 'Next': M: 0.96%, D: 0.77%, H: 0.70%
# Early stopping at epoch 150
# Rs: 160, hid: 8, 2 layers, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.91%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.14%, D: 0.80%, H: 1.02%
# Early stopping at epoch 705
# Rs: 160, hid: 8, 2 layers, lr: 0.0001
#  Train MAPE: 0.81%, Val MAPE: 0.89%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.95%, D: 0.75%, H: 0.93%
# Early stopping at epoch 269
# Rs: 160, hid: 8, 3 layers, lr: 0.001
#  Train MAPE: 1.01%, Val MAPE: 1.06%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.23%, D: 0.92%, H: 1.01%
# Early stopping at epoch 660
# Rs: 160, hid: 8, 3 layers, lr: 0.0001
#  Train MAPE: 0.84%, Val MAPE: 0.88%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.19%, D: 0.67%, H: 0.95%
# Early stopping at epoch 220
# Rs: 160, hid: 8, 4 layers, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.85%, Test MAPE: 0.84%
# Test MAPE by 'Next': M: 0.98%, D: 0.70%, H: 0.83%
# Early stopping at epoch 831
# Rs: 160, hid: 8, 4 layers, lr: 0.0001
#  Train MAPE: 0.83%, Val MAPE: 0.81%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.14%, D: 0.73%, H: 0.90%
# Early stopping at epoch 146
# Rs: 160, hid: 8, 5 layers, lr: 0.001
#  Train MAPE: 0.92%, Val MAPE: 0.93%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.28%, D: 0.84%, H: 1.00%
# Early stopping at epoch 853
# Rs: 160, hid: 8, 5 layers, lr: 0.0001
#  Train MAPE: 0.86%, Val MAPE: 0.83%, Test MAPE: 1.02%
# Test MAPE by 'Next': M: 1.30%, D: 0.77%, H: 1.00%
# Early stopping at epoch 396
# Rs: 160, hid: 8, 6 layers, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.88%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.17%, D: 0.84%, H: 0.82%
# Early stopping at epoch 631
# Rs: 160, hid: 8, 6 layers, lr: 0.0001
#  Train MAPE: 0.79%, Val MAPE: 0.84%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.06%, D: 0.71%, H: 0.97%
# Early stopping at epoch 195
# Rs: 160, hid: 16, 2 layers, lr: 0.001
#  Train MAPE: 0.71%, Val MAPE: 1.03%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.12%, D: 0.68%, H: 1.05%
# Early stopping at epoch 481
# Rs: 160, hid: 16, 2 layers, lr: 0.0001
#  Train MAPE: 0.72%, Val MAPE: 0.85%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.06%, D: 0.76%, H: 0.95%
# Early stopping at epoch 151
# Rs: 160, hid: 16, 3 layers, lr: 0.001
#  Train MAPE: 0.63%, Val MAPE: 0.80%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 1.05%, D: 0.82%, H: 0.75%
# Early stopping at epoch 763
# Rs: 160, hid: 16, 3 layers, lr: 0.0001
#  Train MAPE: 0.67%, Val MAPE: 0.80%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.20%, D: 1.11%, H: 0.85%
# Early stopping at epoch 218
# Rs: 160, hid: 16, 4 layers, lr: 0.001
#  Train MAPE: 0.78%, Val MAPE: 1.03%, Test MAPE: 1.10%
# Test MAPE by 'Next': M: 1.34%, D: 0.92%, H: 1.04%
# Rs: 160, hid: 16, 4 layers, lr: 0.0001
#  Train MAPE: 0.65%, Val MAPE: 0.86%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.30%, D: 0.93%, H: 0.81%
# Early stopping at epoch 189
# Rs: 160, hid: 16, 5 layers, lr: 0.001
#  Train MAPE: 0.70%, Val MAPE: 0.79%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.18%, D: 0.79%, H: 0.86%
# Early stopping at epoch 913
# Rs: 160, hid: 16, 5 layers, lr: 0.0001
#  Train MAPE: 0.61%, Val MAPE: 0.75%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.16%, D: 0.97%, H: 0.86%
# Early stopping at epoch 183
# Rs: 160, hid: 16, 6 layers, lr: 0.001
#  Train MAPE: 0.97%, Val MAPE: 1.01%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.19%, D: 1.05%, H: 0.94%
# Early stopping at epoch 614
# Rs: 160, hid: 16, 6 layers, lr: 0.0001
#  Train MAPE: 0.70%, Val MAPE: 0.85%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.19%, D: 0.80%, H: 0.84%
# Early stopping at epoch 143
# Rs: 160, hid: 32, 2 layers, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 1.34%, Test MAPE: 1.23%
# Test MAPE by 'Next': M: 1.57%, D: 1.11%, H: 1.01%
# Early stopping at epoch 426
# Rs: 160, hid: 32, 2 layers, lr: 0.0001
#  Train MAPE: 0.65%, Val MAPE: 1.52%, Test MAPE: 1.20%
# Test MAPE by 'Next': M: 1.72%, D: 0.93%, H: 0.96%
# Early stopping at epoch 234
# Rs: 160, hid: 32, 3 layers, lr: 0.001
#  Train MAPE: 0.64%, Val MAPE: 1.03%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.33%, D: 0.80%, H: 1.01%
# Early stopping at epoch 404
# Rs: 160, hid: 32, 3 layers, lr: 0.0001
#  Train MAPE: 0.61%, Val MAPE: 1.44%, Test MAPE: 1.13%
# Test MAPE by 'Next': M: 1.56%, D: 0.87%, H: 0.97%
# Early stopping at epoch 120
# Rs: 160, hid: 32, 4 layers, lr: 0.001
#  Train MAPE: 0.89%, Val MAPE: 1.12%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.34%, D: 0.82%, H: 0.97%
# Early stopping at epoch 386
# Rs: 160, hid: 32, 4 layers, lr: 0.0001
#  Train MAPE: 0.60%, Val MAPE: 1.10%, Test MAPE: 1.09%
# Test MAPE by 'Next': M: 1.49%, D: 0.91%, H: 0.85%
# Early stopping at epoch 168
# Rs: 160, hid: 32, 5 layers, lr: 0.001
#  Train MAPE: 0.57%, Val MAPE: 0.83%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.21%, D: 0.75%, H: 0.90%
# Early stopping at epoch 290
# Rs: 160, hid: 32, 5 layers, lr: 0.0001
#  Train MAPE: 0.59%, Val MAPE: 0.89%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.32%, D: 0.82%, H: 0.84%
# Early stopping at epoch 144
# Rs: 160, hid: 32, 6 layers, lr: 0.001
#  Train MAPE: 0.78%, Val MAPE: 1.29%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.29%, D: 0.84%, H: 0.99%
# Early stopping at epoch 396
# Rs: 160, hid: 32, 6 layers, lr: 0.0001
#  Train MAPE: 0.58%, Val MAPE: 0.87%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.23%, D: 0.77%, H: 0.74%
# Early stopping at epoch 349
# Rs: 180, hid: 8, 2 layers, lr: 0.001
#  Train MAPE: 0.64%, Val MAPE: 0.93%, Test MAPE: 1.42%
# Test MAPE by 'Next': M: 1.04%, D: 1.89%, H: 1.33%
# Rs: 180, hid: 8, 2 layers, lr: 0.0001
#  Train MAPE: 0.79%, Val MAPE: 1.47%, Test MAPE: 1.71%
# Test MAPE by 'Next': M: 1.12%, D: 2.26%, H: 1.76%
# Early stopping at epoch 633
# Rs: 180, hid: 8, 3 layers, lr: 0.001
#  Train MAPE: 0.68%, Val MAPE: 1.00%, Test MAPE: 1.09%
# Test MAPE by 'Next': M: 1.11%, D: 1.16%, H: 1.00%
# Rs: 180, hid: 8, 3 layers, lr: 0.0001
#  Train MAPE: 0.73%, Val MAPE: 1.41%, Test MAPE: 1.43%
# Test MAPE by 'Next': M: 1.10%, D: 1.74%, H: 1.46%
# Early stopping at epoch 280
# Rs: 180, hid: 8, 4 layers, lr: 0.001
#  Train MAPE: 0.97%, Val MAPE: 1.23%, Test MAPE: 1.25%
# Test MAPE by 'Next': M: 1.34%, D: 1.22%, H: 1.19%
# Early stopping at epoch 649
# Rs: 180, hid: 8, 4 layers, lr: 0.0001
#  Train MAPE: 0.81%, Val MAPE: 1.29%, Test MAPE: 1.16%
# Test MAPE by 'Next': M: 1.14%, D: 1.05%, H: 1.29%
# Early stopping at epoch 350
# Rs: 180, hid: 8, 5 layers, lr: 0.001
#  Train MAPE: 0.68%, Val MAPE: 0.91%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.07%, D: 0.85%, H: 0.82%
# Early stopping at epoch 547
# Rs: 180, hid: 8, 5 layers, lr: 0.0001
#  Train MAPE: 0.75%, Val MAPE: 0.95%, Test MAPE: 1.08%
# Test MAPE by 'Next': M: 0.89%, D: 1.20%, H: 1.15%
# Early stopping at epoch 215
# Rs: 180, hid: 8, 6 layers, lr: 0.001
#  Train MAPE: 0.65%, Val MAPE: 0.90%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 0.99%, D: 1.05%, H: 1.04%
# Rs: 180, hid: 8, 6 layers, lr: 0.0001
#  Train MAPE: 0.69%, Val MAPE: 0.95%, Test MAPE: 1.21%
# Test MAPE by 'Next': M: 0.89%, D: 1.43%, H: 1.33%
# Early stopping at epoch 394
# Rs: 180, hid: 16, 2 layers, lr: 0.001
#  Train MAPE: 1.10%, Val MAPE: 1.52%, Test MAPE: 1.39%
# Test MAPE by 'Next': M: 1.37%, D: 1.64%, H: 1.16%
# Rs: 180, hid: 16, 2 layers, lr: 0.0001
#  Train MAPE: 0.69%, Val MAPE: 1.54%, Test MAPE: 1.45%
# Test MAPE by 'Next': M: 1.40%, D: 1.49%, H: 1.47%
# Early stopping at epoch 274
# Rs: 180, hid: 16, 3 layers, lr: 0.001
#  Train MAPE: 0.61%, Val MAPE: 1.17%, Test MAPE: 1.12%
# Test MAPE by 'Next': M: 1.12%, D: 1.06%, H: 1.16%
# Rs: 180, hid: 16, 3 layers, lr: 0.0001
#  Train MAPE: 0.71%, Val MAPE: 1.33%, Test MAPE: 1.25%
# Test MAPE by 'Next': M: 1.13%, D: 1.38%, H: 1.26%
# Early stopping at epoch 161
# Rs: 180, hid: 16, 4 layers, lr: 0.001
#  Train MAPE: 0.95%, Val MAPE: 1.43%, Test MAPE: 1.34%
# Test MAPE by 'Next': M: 1.52%, D: 1.41%, H: 1.09%
# Rs: 180, hid: 16, 4 layers, lr: 0.0001
#  Train MAPE: 0.73%, Val MAPE: 1.45%, Test MAPE: 1.38%
# Test MAPE by 'Next': M: 1.11%, D: 1.57%, H: 1.46%
# Early stopping at epoch 278
# Rs: 180, hid: 16, 5 layers, lr: 0.001
#  Train MAPE: 0.53%, Val MAPE: 0.96%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.94%, D: 0.77%, H: 0.87%
# Rs: 180, hid: 16, 5 layers, lr: 0.0001
#  Train MAPE: 0.66%, Val MAPE: 1.20%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 1.14%, D: 0.97%, H: 1.00%
# Early stopping at epoch 341
# Rs: 180, hid: 16, 6 layers, lr: 0.001
#  Train MAPE: 0.62%, Val MAPE: 1.13%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.95%, D: 0.80%, H: 0.83%
# Early stopping at epoch 676
# Rs: 180, hid: 16, 6 layers, lr: 0.0001
#  Train MAPE: 0.71%, Val MAPE: 0.99%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 0.99%, D: 0.95%, H: 0.87%
# Early stopping at epoch 176
# Rs: 180, hid: 32, 2 layers, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 1.30%, Test MAPE: 1.49%
# Test MAPE by 'Next': M: 1.48%, D: 1.70%, H: 1.29%
# Early stopping at epoch 449
# Rs: 180, hid: 32, 2 layers, lr: 0.0001
#  Train MAPE: 0.61%, Val MAPE: 2.14%, Test MAPE: 1.60%
# Test MAPE by 'Next': M: 1.09%, D: 2.06%, H: 1.63%
# Early stopping at epoch 204
# Rs: 180, hid: 32, 3 layers, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 1.32%, Test MAPE: 1.23%
# Test MAPE by 'Next': M: 1.14%, D: 1.39%, H: 1.16%
# Early stopping at epoch 513
# Rs: 180, hid: 32, 3 layers, lr: 0.0001
#  Train MAPE: 0.56%, Val MAPE: 1.66%, Test MAPE: 1.31%
# Test MAPE by 'Next': M: 0.89%, D: 1.77%, H: 1.27%
# Early stopping at epoch 416
# Rs: 180, hid: 32, 4 layers, lr: 0.001
#  Train MAPE: 0.32%, Val MAPE: 1.38%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.14%, D: 0.88%, H: 0.71%
# Early stopping at epoch 283
# Rs: 180, hid: 32, 4 layers, lr: 0.0001
#  Train MAPE: 0.63%, Val MAPE: 1.23%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.18%, D: 0.87%, H: 0.94%
# Early stopping at epoch 141
# Rs: 180, hid: 32, 5 layers, lr: 0.001
#  Train MAPE: 0.58%, Val MAPE: 1.07%, Test MAPE: 1.08%
# Test MAPE by 'Next': M: 1.07%, D: 1.12%, H: 1.05%
# Early stopping at epoch 471
# Rs: 180, hid: 32, 5 layers, lr: 0.0001
#  Train MAPE: 0.50%, Val MAPE: 1.29%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.02%, D: 1.03%, H: 0.94%
# Early stopping at epoch 157
# Rs: 180, hid: 32, 6 layers, lr: 0.001
#  Train MAPE: 0.63%, Val MAPE: 1.06%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 0.97%, D: 1.04%, H: 1.17%
# Early stopping at epoch 614
# Rs: 180, hid: 32, 6 layers, lr: 0.0001
#  Train MAPE: 0.51%, Val MAPE: 1.50%, Test MAPE: 1.14%
# Test MAPE by 'Next': M: 1.04%, D: 1.25%, H: 1.12%

# %%
summary_df = results_df.groupby(['hid', 'nl', 'lr'])[['Train MAPE', 'Val MAPE', 'Test MAPE', 'Next M MAPE', 'Next D MAPE', 'Next H MAPE']].mean().reset_index()
summary_df
summary_df.to_csv('MLP_next_info_sum.csv')
results_df.to_csv('MLP_next_info.csv')
# Out:
#      hid   nl      lr  Train MAPE  Val MAPE  Test MAPE  Next M MAPE  \
# 0    8.0  2.0  0.0001    0.865884  1.067988   1.255957     1.226101
# 1    8.0  2.0  0.0010    0.744302  0.943436   1.069532     1.093780
# 2    8.0  3.0  0.0001    0.813433  1.009996   0.989322     0.997719
# 3    8.0  3.0  0.0010    0.807012  0.924840   0.930212     0.999773
# 4    8.0  4.0  0.0001    0.797533  0.991985   0.922385     0.997800
# 5    8.0  4.0  0.0010    0.815369  0.984236   0.938366     1.019785
# 6    8.0  5.0  0.0001    0.790868  0.926105   0.928301     1.004990
# 7    8.0  5.0  0.0010    0.803617  0.965221   0.953025     1.079794
# 8    8.0  6.0  0.0001    0.995585  1.087586   1.105717     1.120737
# 9    8.0  6.0  0.0010    0.983781  1.085691   1.064701     1.174054
# 10  16.0  2.0  0.0001    0.747250  1.162839   1.123318     1.219268
# 11  16.0  2.0  0.0010    0.870589  1.169809   1.112565     1.227860
# 12  16.0  3.0  0.0001    0.677030  1.023482   1.046546     1.062202
# 13  16.0  3.0  0.0010    0.694306  0.983255   1.000334     1.133316
# 14  16.0  4.0  0.0001    0.787357  1.171573   1.130556     1.164080
# 15  16.0  4.0  0.0010    0.811598  1.089862   1.048482     1.219453
# 16  16.0  5.0  0.0001    0.668932  0.926580   0.932484     1.065945
# 17  16.0  5.0  0.0010    0.656998  0.888622   0.865213     0.994265
# 18  16.0  6.0  0.0001    0.713749  0.946951   0.894913     1.030368
# 19  16.0  6.0  0.0010    0.759645  1.040796   0.906494     1.042465
# 20  32.0  2.0  0.0001    0.639095  1.536738   1.226057     1.324855
# 21  32.0  2.0  0.0010    0.799856  1.253687   1.256692     1.414071
# 22  32.0  3.0  0.0001    0.642924  1.347941   1.199056     1.263787
# 23  32.0  3.0  0.0010    0.805304  1.170904   1.179276     1.256746
# 24  32.0  4.0  0.0001    0.609864  1.088352   1.007029     1.169234
# 25  32.0  4.0  0.0010    0.650125  1.199824   0.972642     1.143158
# 26  32.0  5.0  0.0001    0.603916  1.049001   0.954993     1.118218
# 27  32.0  5.0  0.0010    0.621106  1.045092   0.955427     1.104777
# 28  32.0  6.0  0.0001    0.645532  1.033472   0.954890     1.069028
# 29  32.0  6.0  0.0010    0.712951  1.024054   0.963463     1.085550
#
#     Next D MAPE  Next H MAPE
# 0      1.176879     1.364891
# 1      1.116551     0.998264
# 2      1.003573     0.966674
# 3      0.955323     0.835541
# 4      0.869145     0.900211
# 5      0.917717     0.877595
# 6      0.843939     0.935974
# 7      0.862945     0.916334
# 8      1.096903     1.099511
# 9      1.067966     0.952084
# 10     0.984360     1.166326
# 11     1.042951     1.066883
# 12     1.032920     1.044516
# 13     0.884268     0.983419
# 14     1.127832     1.099757
# 15     0.977548     0.948445
# 16     0.904549     0.826958
# 17     0.788541     0.812834
# 18     0.830551     0.823821
# 19     0.884963     0.792055
# 20     1.174196     1.179119
# 21     1.243747     1.112257
# 22     1.200510     1.132871
# 23     1.139013     1.142069
# 24     0.892917     0.958936
# 25     0.927468     0.847301
# 26     0.847339     0.899421
# 27     0.866286     0.895218
# 28     0.894743     0.900898
# 29     0.834075     0.970763
