# %%
import pandas as pd
import numpy as np
import random
import os
import time
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
import time

from numpy import hstack, vstack
import itertools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from itertools import product

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

from torch.utils.data import DataLoader, TensorDataset

import warnings
warnings.filterwarnings(action='ignore')

# %%
def find_directory(foldername, filename = None, back_num = 0):
    cur = os.getcwd()
    for i in range(back_num):
        cur = os.path.abspath(os.path.join(cur, os.pardir))
    for folder in foldername:
        cur = os.path.join(cur, folder)
    if not os.path.exists(cur):
        os.makedirs(cur)
        print(f'{cur} created')
    if filename != None:
        cur = os.path.join(cur, filename)
    return cur

os.getcwd()
# Out:
# 'c:\\Users\\dkstj\\Desktop\\연구\\현대차 3차\\Rapid_fin\\deep learning modeling'

# %%
csv_add = find_directory(foldername = [], filename = 'SOC_Point_Data.csv')
dat = pd.read_csv(csv_add, index_col = (0,1,2,3,4))

# %%
def Get_Data(dat) :
    
    RPT_MODE = "0.1C"
    SOC_Range = [9,10,11,12]

    Time_Range = range(6, 15, 2)
    SOC_Range = [str(i) for i in SOC_Range]
    

    Data = dat

    X = Data.loc[RPT_MODE, "0" : "16"]
    Y = Data.loc[RPT_MODE, ["SOH", "Next_SOH", "Ratio_SOH", "Ratio_CYC"]].groupby(level = ["Next", "Path", "Number"]).mean()
    
    y = pd.Series(Y["Next_SOH"] - Y["SOH"], name = "Delta_SOH")
    
    Y = pd.concat([Y, y], axis = 1)

    X_seek = X.loc[X.index.get_level_values("Time").isin(Time_Range), SOC_Range]


    X_std = X_seek.groupby(level = ["Next", "Path", "Number"]).std()
    
    return X_std, Y

# %%
def Even_Split(X, y, test_size, rs) :

    X_M = X.xs(key = 'M', level = 'Next', drop_level = False)
    X_D = X.xs(key = 'D', level = 'Next', drop_level = False)
    X_H = X.xs(key = 'H', level = 'Next', drop_level = False)
    
    XX = {"M" : X_M, "D" : X_D, "H" : X_H}
    
    y_M = y.xs(key = 'M', level = 'Next', drop_level = False)
    y_D = y.xs(key = 'D', level = 'Next', drop_level = False)
    y_H = y.xs(key = 'H', level = 'Next', drop_level = False)
    
    yy = {"M" : y_M, "D" : y_D, "H" : y_H}
    
    
    XXX = {"M" : [], "D" : [], "H" : []}
    
    yyy = {"M" : [], "D" : [], "H" : []}
    
    
    for n in ["M", "D", "H"] :
        for path in range(1,5) :
            X_path = XX[n].loc[XX[n].index.get_level_values(level = 'Path').str.len() == path]
            y_path = yy[n].loc[yy[n].index.get_level_values(level = 'Path').str.len() == path]
            
            XXX[n].append(X_path)
            yyy[n].append(y_path)
            
            
    XX_tn = {"M" : [], "D" : [], "H" : []}
    XX_te = {"M" : [], "D" : [], "H" : []}
    
    yy_tn = {"M" : [], "D" : [], "H" : []}
    yy_te = {"M" : [], "D" : [], "H" : []}
        
    for n in ["M", "D", "H"] :
        for path in range(1,5) :
            X_temp = XXX[n][path-1]
            y_temp = yyy[n][path-1]
            
            X_tn, X_te, y_tn, y_te = train_test_split(X_temp, y_temp, test_size = test_size, random_state = rs)
            
            XX_tn[n].append(X_tn)
            XX_te[n].append(X_te)
            yy_tn[n].append(y_tn)
            yy_te[n].append(y_te)
                  
    for n in ["M", "D", "H"] :
        XX_tn[n] = pd.concat(XX_tn[n])
        XX_te[n] = pd.concat(XX_te[n])
        yy_tn[n] = pd.concat(yy_tn[n])
        yy_te[n] = pd.concat(yy_te[n])
        
        
    X_tn = pd.concat(XX_tn.values())
    X_te = pd.concat(XX_te.values())
    
    y_tn = pd.concat(yy_tn.values())
    y_te = pd.concat(yy_te.values())
    
    return X_tn, X_te, y_tn, y_te

# %%
def convert_to_tensor(X_tn, X_te, y_tn, y_te, batch_size=32, val_size=0.2, rs=100):
    """
    X_tn, X_te: MultiIndex DataFrame (Next, Path, Number, Time)
    y_tn, y_te: Series or DataFrame with index (Next, Path, Number)
    """

    X_tr, X_vl, y_tr, y_vl = Even_Split(X_tn, y_tn, val_size, rs)
    keys_train = y_tr.index
    keys_val = y_vl.index

    scaler = StandardScaler()
    X_tn_scaled = X_tn.copy()
    X_te_scaled = X_te.copy()

    scaler.fit(X_tn.values)
    X_tn_scaled.loc[:, :] = scaler.transform(X_tn.values)
    X_te_scaled.loc[:, :] = scaler.transform(X_te.values)

    next_map = {'M': 0, 'D': 1, 'H': 2}
    get_next = lambda idx: torch.nn.functional.one_hot(torch.tensor([next_map[i] for i in idx.get_level_values("Next")]), num_classes=3).float()

    def to_tensor(X_df, y_df, keys):
        X_group = X_df.groupby(level=["Next", "Path", "Number"])
        X_tensor = torch.stack([
            torch.tensor(X_group.get_group(k).values.T, dtype=torch.float32)
            for k in keys
        ])
        y_tensor = torch.tensor(y_df.loc[keys].values, dtype=torch.float32).unsqueeze(1)
        return X_tensor, y_tensor

    next_train = get_next(pd.MultiIndex.from_tuples(keys_train, names=["Next", "Path", "Number"]))
    next_val   = get_next(pd.MultiIndex.from_tuples(keys_val,   names=["Next", "Path", "Number"]))
    next_test  = get_next(y_te.index)
    
    X_train_tensor, y_train_tensor = to_tensor(X_tn_scaled, y_tn, keys_train)
    X_val_tensor,   y_val_tensor   = to_tensor(X_tn_scaled, y_tn, keys_val)
    X_test_tensor,  y_test_tensor  = to_tensor(X_te_scaled, y_te, y_te.index.drop_duplicates())

    train_loader = DataLoader(TensorDataset(X_train_tensor, next_train, y_train_tensor), batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(TensorDataset(X_val_tensor, next_val,  y_val_tensor),   batch_size=batch_size, shuffle=False)
    test_loader  = DataLoader(TensorDataset(X_test_tensor, next_test,  y_test_tensor),  batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader, X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor, X_test_tensor, y_test_tensor, scaler

# %%
def setRandomSeed(random_seed=0):
    os.environ['PYTHONHASHSEED'] = str(random_seed)
    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(random_seed)
    random.seed(random_seed)

# %%
class Trainer:
    def __init__(self, model, lr=1e-3, weight_decay=0, epoch=1000, patience=50, random_seed = 0):
        self.random_seed = random_seed
        #setRandomSeed(self.random_seed)
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.model = model.to(self.device)
        self.criterion = nn.MSELoss()
        self.cri2 = MAPELoss()
        self.optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.StepLR(self.optimizer, step_size=200, gamma=0.8)
        self.epoch = epoch
        self.patience = patience

        self.train_loss = []
        self.test_loss = []
        self.val_loss = []

    def train(self, train_loader, test_loader=None, val_loader=None):
        best_val_loss = float('inf')
        best_model_state = None
        epochs_no_improve = 0

        for ep in range(1, self.epoch + 1):
            self.model.train()
            for x_batch, onehot, y_batch in train_loader:
                x_batch, onehot, y_batch = x_batch.to(self.device), onehot.to(self.device), y_batch.to(self.device)

                self.optimizer.zero_grad()
                outputs = self.model(x_batch, onehot)
                loss = self.cri2(outputs, y_batch)
                loss.backward()
                self.optimizer.step()

            self.scheduler.step()

            avg_train_loss = self.evaluate(train_loader)
            test_loss = self.evaluate(test_loader) if test_loader else None
            val_loss = self.evaluate(val_loader) if val_loader else None

            self.train_loss.append(avg_train_loss)
            self.test_loss.append(test_loss)
            self.val_loss.append(val_loss)

            if val_loader:
                if val_loss < best_val_loss - 1e-4:
                    best_val_loss = val_loss
                    best_model_state = self.model.state_dict()
                    epochs_no_improve = 0
                else:
                    epochs_no_improve += 1
                    if epochs_no_improve >= self.patience:
                        print(f"Early stopping at epoch {ep}")
                        break

        if best_model_state:
            self.model.load_state_dict(best_model_state)

    def evaluate(self, data_loader):
        if data_loader is None:
            return None
        self.model.eval()
        total_loss = 0
        with torch.no_grad():
            for x_batch, onehot, y_batch in data_loader:
                x_batch, onehot, y_batch = x_batch.to(self.device), onehot.to(self.device), y_batch.to(self.device)
                outputs = self.model(x_batch, onehot)
                loss = self.cri2(outputs, y_batch)
                total_loss += loss.item()
        return total_loss / len(data_loader)

    def predict(self, x, onehot):
        self.model.eval()
        with torch.no_grad():
            x = x.to(self.device)
            onehot = onehot.to(self.device)
            return self.model(x, onehot)

# %%
def plot_results(model, info, train_loader, val_loader, test_loader, plot = True):
    rs, rnn_hid, rnn_layer, rnn_out, fc_hid, fc_layer, lr = info
    
    y_true_train = []
    y_pred_train = []
    
    y_true_val = []
    y_pred_val = []
    
    y_true_test = []
    y_pred_test = []

    y_true_test_M = []
    y_pred_test_M = []

    y_true_test_D = []
    y_pred_test_D = []

    y_true_test_H = []
    y_pred_test_H = []
    
    for x_batch, onehot, y_batch in train_loader:
        preds = trainer.predict(x_batch, onehot)
        y_true_train.append(y_batch)
        y_pred_train.append(preds.cpu())
    
    for x_batch, onehot, y_batch in val_loader:
        preds = trainer.predict(x_batch, onehot)
        y_true_val.append(y_batch)
        y_pred_val.append(preds.cpu())
    
    for x_batch, onehot, y_batch in test_loader:
        preds = trainer.predict(x_batch, onehot)
        y_true_test.append(y_batch)
        y_pred_test.append(preds.cpu())
    
        onehot_np = onehot.cpu().numpy()
        y_true_np = y_batch.cpu().numpy()
        y_pred_np = preds.cpu().numpy()
    
        for i in range(len(onehot_np)):
            if np.array_equal(onehot_np[i], [1, 0, 0]):  # 'M'
                y_true_test_M.append(y_true_np[i])
                y_pred_test_M.append(y_pred_np[i])
            elif np.array_equal(onehot_np[i], [0, 1, 0]):  # 'D'
                y_true_test_D.append(y_true_np[i])
                y_pred_test_D.append(y_pred_np[i])
            elif np.array_equal(onehot_np[i], [0, 0, 1]):  # 'H'
                y_true_test_H.append(y_true_np[i])
                y_pred_test_H.append(y_pred_np[i])
    
    y_true_train = torch.cat(y_true_train).numpy()
    y_pred_train = torch.cat(y_pred_train).numpy()
    
    y_true_val = torch.cat(y_true_val).numpy()
    y_pred_val = torch.cat(y_pred_val).numpy()
    
    y_true_test = torch.cat(y_true_test).numpy()
    y_pred_test = torch.cat(y_pred_test).numpy()

    y_true_test_M = np.array(y_true_test_M)
    y_pred_test_M = np.array(y_pred_test_M)
    
    y_true_test_D = np.array(y_true_test_D)
    y_pred_test_D = np.array(y_pred_test_D)
    
    y_true_test_H = np.array(y_true_test_H)
    y_pred_test_H = np.array(y_pred_test_H)
    
    mape_M = mean_absolute_percentage_error(y_true_test_M, y_pred_test_M) * 100 if len(y_true_test_M) > 0 else np.nan
    mape_D = mean_absolute_percentage_error(y_true_test_D, y_pred_test_D) * 100 if len(y_true_test_D) > 0 else np.nan
    mape_H = mean_absolute_percentage_error(y_true_test_H, y_pred_test_H) * 100 if len(y_true_test_H) > 0 else np.nan
    
    train_mape = mean_absolute_percentage_error(y_true_train, y_pred_train) * 100
    val_mape = mean_absolute_percentage_error(y_true_val, y_pred_val) * 100
    test_mape = mean_absolute_percentage_error(y_true_test, y_pred_test) * 100
    print(f"Model: {model}, rs: {rs}, rnn_hid: {rnn_hid}, rnn_layer: {rnn_layer}, rnn_out: {rnn_out}, fc_hid: {fc_hid}, fc_layer: {fc_layer}, lr: {lr}\n Train MAPE: {train_mape:.2f}%, Val MAPE: {val_mape:.2f}%, Test MAPE: {test_mape:.2f}%")
    print(f"Test MAPE by 'Next': M: {mape_M:.2f}%, D: {mape_D:.2f}%, H: {mape_H:.2f}%")
    
    if plot == True:
        _ = plt.figure()
        _ = plt.scatter(y_true_train, y_pred_train, label = 'Train')
        _ = plt.scatter(y_true_val, y_pred_val, label = 'Val')
        _ = plt.scatter(y_true_test, y_pred_test, label = 'Test')
        min_val = min(y_true_train.min(), y_true_test.min())
        max_val = max(y_true_train.max(), y_true_test.max())
        _ = plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Ideal line')
        _ = plt.xlabel('True SOH')
        _ = plt.ylabel('Predicted SOH')
        _ = plt.legend()
        _ = plt.title(f'Random state: {rs}, hid: {hid}, {nl} layer, lr: {lr}')
    return train_mape, val_mape, test_mape, mape_M, mape_D, mape_H

def plot_loss(info, train_loss, val_loss, test_loss):
    rs, c1, c2, k1, k2 = info
    _ = plt.figure()
    _ = plt.plot(train_loss, label = 'Train loss')
    _ = plt.plot(val_loss, label = 'Val loss')
    _ = plt.plot(test_loss, label = 'Test loss')
    _ = plt.ylim([0, 2])
    _ = plt.xlabel('Epoch')
    _ = plt.ylabel('Loss')
    _ = plt.legend()
    _ = plt.title(f'Random state: {rs}, hid: {hid}, {nl} layers, lr: {lr}')

# %% [markdown]
# ## GRU

# %%
class GRU_Compressor(nn.Module):
    def __init__(self, input_dim=1, hidden_dim=64, num_layers=1, output_dim=1):
        super(GRU_Compressor, self).__init__()
        self.gru = nn.GRU(input_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        output, h_n = self.gru(x)
        h_last = h_n[-1]
        return self.fc(h_last)

# %%
class GRU_MLP(nn.Module):
    def __init__(self, rnn_hid = 64, rnn_layers = 1, in_dim = 1, out_dim=4, hidden_dim=64, num_layers=2, next_dim = 3):
        super(GRU_MLP, self).__init__()
        self.encoder = GRU_Compressor(in_dim, rnn_hid, rnn_layers, out_dim)
        
        layers = []

        input_dim = out_dim + next_dim
        output_dim = 1

        layers.append(nn.Linear(input_dim, hidden_dim))
        layers.append(nn.ReLU())

        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(nn.ReLU())

        layers.append(nn.Linear(hidden_dim, output_dim))

        self.model = nn.Sequential(*layers)

    def forward(self, x, onehot):
        x_feat = self.encoder(x)
        x_concat = torch.cat([x_feat, onehot], dim=1)
        return self.model(x_concat)

class MAPELoss(nn.Module):
    def __init__(self, epsilon=1e-7):
        super(MAPELoss, self).__init__()
        self.epsilon = epsilon

    def forward(self, y_pred, y_true):
        return torch.mean(torch.abs((y_true - y_pred) / (y_true + self.epsilon))) * 100

# %% [markdown]
# ## Test

# %%
random_states = [100, 120, 140, 160, 180]
bs = 12
ep = 1000

rnn_hids   = [4, 8, 16, 32]
rnn_layers = [1, 2, 3]
rnn_outs   = [2, 4, 8]
fc_hids    = [4, 8, 16]
fc_layers  = [1, 2, 3]
lrs        = [1e-3, 1e-2]

results_df = pd.DataFrame(columns = ['rs', 'rnn_hids', 'rnn_layers', 'rnn_outs', 'fc_hids', 'fc_layers', 'lrs', 'Train MAPE', 'Val MAPE', 'Test MAPE', 'Next M MAPE', 'Next D MAPE', 'Next H MAPE'])

X, Y = Get_Data(dat)

y = Y["Next_SOH"]

for rs, rnn_hid, rnn_layer, rnn_out, fc_hid, fc_layer, lr in product(random_states, rnn_hids, rnn_layers, rnn_outs, fc_hids, fc_layers, lrs):
    setRandomSeed(rs)
    start = time.time()
    X_tn, X_te, y_tn, y_te = Even_Split(X, y, 1/3, rs)
    train_loader, val_loader, test_loader, X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor, X_test_tensor, y_test_tensor, scaler = convert_to_tensor(X_tn, X_te, y_tn, y_te, bs, 1/6, rs)

    model = GRU_MLP(rnn_hid, rnn_layer, 1, rnn_out, fc_hid, fc_layer)
    trainer = Trainer(model, lr=lr, epoch = ep, random_seed = rs)
    
    trainer.train(train_loader, val_loader, test_loader)

    info = [rs, rnn_hid, rnn_layer, rnn_out, fc_hid, fc_layer, lr]
    results = plot_results("GRU", info, train_loader, val_loader, test_loader, plot = False)

    temp_df = pd.DataFrame(info+list(results)).T
    temp_df.columns = ['rs', 'rnn_hids', 'rnn_layers', 'rnn_outs', 'fc_hids', 'fc_layers', 'lrs', 'Train MAPE', 'Val MAPE', 'Test MAPE', 'Next M MAPE', 'Next D MAPE', 'Next H MAPE']
    results_df = pd.concat([results_df, temp_df])
    print(f"{time.time()-start:.2f} s")
# Out:
# Early stopping at epoch 100
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.91%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.95%, D: 0.82%, H: 0.84%
# 6.75 s
# Early stopping at epoch 68
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.13%, Val MAPE: 1.12%, Test MAPE: 1.09%
# Test MAPE by 'Next': M: 0.99%, D: 0.95%, H: 1.34%
# 4.47 s
# Early stopping at epoch 85
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.14%, Val MAPE: 1.08%, Test MAPE: 1.21%
# Test MAPE by 'Next': M: 1.30%, D: 1.00%, H: 1.34%
# 5.73 s
# Early stopping at epoch 67
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.86%, Val MAPE: 0.88%, Test MAPE: 0.97%
# Test MAPE by 'Next': M: 0.95%, D: 0.86%, H: 1.08%
# 4.05 s
# Early stopping at epoch 136
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.92%, Val MAPE: 0.90%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.95%, D: 0.91%, H: 0.82%
# 9.06 s
# Early stopping at epoch 75
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.30%, Val MAPE: 1.13%, Test MAPE: 1.41%
# Test MAPE by 'Next': M: 1.44%, D: 1.13%, H: 1.67%
# 5.51 s
# Early stopping at epoch 72
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.92%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.84%, D: 0.92%, H: 0.79%
# 4.80 s
# Early stopping at epoch 61
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.14%, Val MAPE: 1.02%, Test MAPE: 1.18%
# Test MAPE by 'Next': M: 1.40%, D: 1.18%, H: 0.96%
# 3.99 s
# Early stopping at epoch 134
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.02%, Val MAPE: 1.03%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 1.14%, D: 1.06%, H: 0.89%
# 9.36 s
# Early stopping at epoch 55
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.03%, Val MAPE: 1.00%, Test MAPE: 1.17%
# Test MAPE by 'Next': M: 1.22%, D: 0.98%, H: 1.30%
# 3.88 s
# Early stopping at epoch 69
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.91%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.99%, D: 0.85%, H: 0.81%
# 4.94 s
# Early stopping at epoch 171
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.76%, Val MAPE: 0.93%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.10%, D: 0.82%, H: 0.83%
# 12.11 s
# Early stopping at epoch 87
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.91%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.93%, D: 0.83%, H: 0.82%
# 5.69 s
# Early stopping at epoch 146
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.93%, Val MAPE: 1.01%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.01%, D: 1.09%, H: 0.73%
# 9.52 s
# Early stopping at epoch 147
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.99%, Val MAPE: 1.13%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 0.98%, D: 1.25%, H: 0.81%
# 10.24 s
# Early stopping at epoch 139
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.04%, Val MAPE: 1.04%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 0.91%, D: 1.18%, H: 0.87%
# 9.38 s
# Early stopping at epoch 146
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.90%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.94%, D: 0.82%, H: 0.83%
# 9.72 s
# Early stopping at epoch 78
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.08%, Val MAPE: 1.09%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.16%, D: 1.16%, H: 0.82%
# 5.91 s
# Early stopping at epoch 98
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.87%, Val MAPE: 1.02%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.05%, D: 0.86%, H: 0.97%
# 6.61 s
# Early stopping at epoch 80
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.11%, Val MAPE: 1.09%, Test MAPE: 1.19%
# Test MAPE by 'Next': M: 1.12%, D: 0.87%, H: 1.59%
# 5.45 s
# Early stopping at epoch 106
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.87%, Val MAPE: 1.04%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.88%, D: 0.78%, H: 0.88%
# 8.01 s
# Early stopping at epoch 59
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.00%, Val MAPE: 1.03%, Test MAPE: 1.02%
# Test MAPE by 'Next': M: 1.01%, D: 1.07%, H: 0.98%
# 4.68 s
# Early stopping at epoch 106
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.89%, Val MAPE: 0.87%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.98%, D: 0.81%, H: 0.92%
# 7.88 s
# Early stopping at epoch 128
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.39%, Val MAPE: 1.35%, Test MAPE: 1.53%
# Test MAPE by 'Next': M: 1.63%, D: 1.37%, H: 1.60%
# 9.66 s
# Early stopping at epoch 446
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 0.91%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.97%, D: 0.83%, H: 0.75%
# 30.13 s
# Early stopping at epoch 188
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.26%, Val MAPE: 1.13%, Test MAPE: 1.32%
# Test MAPE by 'Next': M: 1.26%, D: 1.21%, H: 1.50%
# 13.73 s
# Early stopping at epoch 96
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.87%, Val MAPE: 0.95%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.02%, D: 0.84%, H: 0.92%
# 6.80 s
# Early stopping at epoch 121
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.89%, Val MAPE: 0.90%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 0.97%, D: 1.12%, H: 0.70%
# 8.60 s
# Early stopping at epoch 122
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.89%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 9.80 s
# Early stopping at epoch 60
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.98%, Val MAPE: 2.14%, Test MAPE: 2.00%
# Test MAPE by 'Next': M: 2.17%, D: 1.98%, H: 1.85%
# 5.22 s
# Early stopping at epoch 87
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.15%, Val MAPE: 1.29%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.27%, D: 1.36%, H: 0.71%
# 5.71 s
# Early stopping at epoch 82
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.27%, Val MAPE: 1.11%, Test MAPE: 1.32%
# Test MAPE by 'Next': M: 1.06%, D: 1.92%, H: 0.97%
# 5.26 s
# Early stopping at epoch 89
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.86%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.94%, D: 0.82%, H: 0.88%
# 6.06 s
# Early stopping at epoch 59
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.38%, Val MAPE: 1.44%, Test MAPE: 1.32%
# Test MAPE by 'Next': M: 1.59%, D: 1.29%, H: 1.09%
# 4.33 s
# Early stopping at epoch 86
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.95%, Val MAPE: 0.92%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.05%, D: 0.82%, H: 1.11%
# 6.66 s
# Early stopping at epoch 77
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.90%, Val MAPE: 0.89%, Test MAPE: 0.84%
# Test MAPE by 'Next': M: 0.91%, D: 0.79%, H: 0.81%
# 5.92 s
# Early stopping at epoch 89
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.94%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.99%, D: 0.95%, H: 0.78%
# 6.05 s
# Early stopping at epoch 84
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.22%, Val MAPE: 1.15%, Test MAPE: 1.28%
# Test MAPE by 'Next': M: 1.31%, D: 1.03%, H: 1.51%
# 5.82 s
# Early stopping at epoch 250
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 18.85 s
# Early stopping at epoch 73
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.83%, Val MAPE: 1.94%, Test MAPE: 1.85%
# Test MAPE by 'Next': M: 1.99%, D: 1.81%, H: 1.74%
# 5.58 s
# Early stopping at epoch 186
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.91%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.97%, D: 1.80%, H: 1.73%
# 14.16 s
# Early stopping at epoch 70
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.91%, Val MAPE: 1.90%, Test MAPE: 1.85%
# Test MAPE by 'Next': M: 1.93%, D: 1.79%, H: 1.82%
# 5.04 s
# Early stopping at epoch 81
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.92%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.94%, D: 0.82%, H: 0.80%
# 5.14 s
# Early stopping at epoch 121
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.75%, Val MAPE: 1.56%, Test MAPE: 1.87%
# Test MAPE by 'Next': M: 1.44%, D: 1.67%, H: 2.49%
# 8.21 s
# Early stopping at epoch 91
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.79%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 0.97%, D: 0.84%, H: 0.97%
# 6.67 s
# Early stopping at epoch 93
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.00%, Val MAPE: 1.12%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.10%, D: 1.04%, H: 0.83%
# 7.13 s
# Early stopping at epoch 91
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.94%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.89%, D: 0.88%, H: 0.81%
# 7.39 s
# Early stopping at epoch 78
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.06%, Val MAPE: 1.18%, Test MAPE: 1.02%
# Test MAPE by 'Next': M: 1.02%, D: 1.13%, H: 0.91%
# 6.04 s
# Early stopping at epoch 101
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.82%, Val MAPE: 0.90%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.97%, D: 0.82%, H: 0.82%
# 6.47 s
# Early stopping at epoch 58
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.49%, Val MAPE: 1.33%, Test MAPE: 1.56%
# Test MAPE by 'Next': M: 1.77%, D: 1.29%, H: 1.62%
# 3.74 s
# Early stopping at epoch 78
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.00%, Val MAPE: 1.13%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 0.97%, D: 1.04%, H: 0.95%
# 5.34 s
# Early stopping at epoch 72
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.88%, Val MAPE: 0.94%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 0.99%, D: 0.79%, H: 1.03%
# 5.17 s
# Early stopping at epoch 93
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.92%, Val MAPE: 0.97%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.15%, D: 0.82%, H: 0.99%
# 7.12 s
# Early stopping at epoch 78
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 1, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.00%, Val MAPE: 0.84%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.19%, D: 0.99%, H: 0.81%
# 6.00 s
# Early stopping at epoch 125
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.88%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.95%, D: 1.79%, H: 1.73%
# 9.19 s
# Early stopping at epoch 66
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.90%, Val MAPE: 1.90%, Test MAPE: 1.84%
# Test MAPE by 'Next': M: 1.93%, D: 1.78%, H: 1.81%
# 4.97 s
# Early stopping at epoch 117
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.87%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.94%, D: 1.79%, H: 1.72%
# 9.53 s
# Early stopping at epoch 61
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.83%, Val MAPE: 1.87%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.94%, D: 1.79%, H: 1.72%
# 5.08 s
# Early stopping at epoch 288
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.83%, Val MAPE: 1.93%, Test MAPE: 1.84%
# Test MAPE by 'Next': M: 1.98%, D: 1.81%, H: 1.74%
# 22.48 s
# Early stopping at epoch 81
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.86%, Val MAPE: 1.98%, Test MAPE: 1.86%
# Test MAPE by 'Next': M: 2.02%, D: 1.83%, H: 1.74%
# 7.14 s
# Early stopping at epoch 111
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.89%, Val MAPE: 0.96%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.96%, D: 0.83%, H: 0.80%
# 8.74 s
# Early stopping at epoch 109
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.30%, Val MAPE: 1.26%, Test MAPE: 1.39%
# Test MAPE by 'Next': M: 1.22%, D: 1.18%, H: 1.77%
# 8.50 s
# Early stopping at epoch 110
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.91%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.88%, D: 0.83%, H: 0.87%
# 8.03 s
# Early stopping at epoch 162
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 2.16%, Val MAPE: 2.09%, Test MAPE: 2.27%
# Test MAPE by 'Next': M: 2.72%, D: 1.90%, H: 2.18%
# 11.77 s
# Early stopping at epoch 141
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.88%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.92%, D: 0.82%, H: 0.91%
# 11.33 s
# Early stopping at epoch 149
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.77%, Val MAPE: 0.84%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 1.16%, D: 0.82%, H: 0.70%
# 12.35 s
# Early stopping at epoch 97
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.14%, Val MAPE: 1.21%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.35%, D: 1.11%, H: 0.88%
# 7.67 s
# Early stopping at epoch 141
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.00%, Val MAPE: 0.88%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 1.00%, D: 0.89%, H: 1.20%
# 11.07 s
# Early stopping at epoch 65
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.00%, Val MAPE: 1.09%, Test MAPE: 0.97%
# Test MAPE by 'Next': M: 0.95%, D: 1.02%, H: 0.94%
# 5.60 s
# Early stopping at epoch 135
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.11%, Val MAPE: 1.13%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 0.93%, D: 1.24%, H: 0.92%
# 9.84 s
# Early stopping at epoch 87
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.09%, Val MAPE: 1.17%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.10%, D: 1.17%, H: 0.87%
# 6.72 s
# Early stopping at epoch 172
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.07%, Val MAPE: 1.02%, Test MAPE: 1.13%
# Test MAPE by 'Next': M: 1.10%, D: 0.88%, H: 1.41%
# 14.17 s
# Early stopping at epoch 88
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.86%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.90%, D: 0.82%, H: 0.81%
# 6.48 s
# Early stopping at epoch 55
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.33%, Val MAPE: 1.10%, Test MAPE: 1.38%
# Test MAPE by 'Next': M: 1.22%, D: 1.69%, H: 1.24%
# 4.38 s
# Early stopping at epoch 243
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 18.63 s
# Early stopping at epoch 63
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 2.00%, Val MAPE: 1.97%, Test MAPE: 1.91%
# Test MAPE by 'Next': M: 1.96%, D: 1.84%, H: 1.94%
# 4.68 s
# Early stopping at epoch 95
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.91%, Test MAPE: 0.81%
# Test MAPE by 'Next': M: 0.85%, D: 0.81%, H: 0.78%
# 7.40 s
# Early stopping at epoch 109
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.75%, Val MAPE: 0.79%, Test MAPE: 0.83%
# Test MAPE by 'Next': M: 0.96%, D: 0.81%, H: 0.72%
# 8.92 s
# Early stopping at epoch 71
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.91%, Val MAPE: 0.93%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.93%, D: 0.90%, H: 0.83%
# 5.29 s
# Early stopping at epoch 117
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.14%, Val MAPE: 1.17%, Test MAPE: 1.08%
# Test MAPE by 'Next': M: 1.11%, D: 1.35%, H: 0.79%
# 8.60 s
# Early stopping at epoch 113
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.93%, Val MAPE: 0.95%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 0.97%, D: 0.85%, H: 1.07%
# 8.89 s
# Early stopping at epoch 160
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.10%, Val MAPE: 1.22%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.15%, D: 1.13%, H: 0.88%
# 12.83 s
# Early stopping at epoch 78
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.95%, Val MAPE: 1.07%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 0.99%, D: 0.99%, H: 0.86%
# 6.28 s
# Early stopping at epoch 115
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.16%, Val MAPE: 1.12%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.12%, D: 1.23%, H: 0.98%
# 9.04 s
# Early stopping at epoch 76
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.84%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.91%, D: 0.81%, H: 0.92%
# 5.42 s
# Early stopping at epoch 149
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.98%, Val MAPE: 1.01%, Test MAPE: 0.97%
# Test MAPE by 'Next': M: 0.93%, D: 1.10%, H: 0.87%
# 10.72 s
# Early stopping at epoch 95
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.82%, Test MAPE: 0.83%
# Test MAPE by 'Next': M: 0.86%, D: 0.85%, H: 0.77%
# 7.79 s
# Early stopping at epoch 172
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.78%, Val MAPE: 1.01%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.06%, D: 0.81%, H: 0.91%
# 14.14 s
# Early stopping at epoch 108
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.84%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.90%, D: 0.83%, H: 0.85%
# 10.13 s
# Early stopping at epoch 134
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.01%, Val MAPE: 0.94%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.03%, D: 0.92%, H: 1.23%
# 12.56 s
# Early stopping at epoch 96
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.88%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.86%, D: 0.83%, H: 0.91%
# 8.02 s
# Early stopping at epoch 112
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.78%, Val MAPE: 0.80%, Test MAPE: 0.82%
# Test MAPE by 'Next': M: 0.92%, D: 0.86%, H: 0.69%
# 7.76 s
# Early stopping at epoch 82
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.98%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.88%, D: 0.92%, H: 0.83%
# 6.44 s
# Early stopping at epoch 120
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.87%, Val MAPE: 0.84%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.96%, D: 0.98%, H: 0.77%
# 9.38 s
# Early stopping at epoch 176
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 15.01 s
# Early stopping at epoch 65
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.85%, Val MAPE: 1.87%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.92%, D: 1.78%, H: 1.75%
# 5.05 s
# Early stopping at epoch 78
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.96%, Test MAPE: 0.84%
# Test MAPE by 'Next': M: 0.87%, D: 0.81%, H: 0.84%
# 5.44 s
# Early stopping at epoch 138
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.90%, Val MAPE: 0.84%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.12%, D: 0.98%, H: 0.70%
# 10.11 s
# Early stopping at epoch 82
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.89%, Val MAPE: 0.84%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.97%, D: 0.80%, H: 0.96%
# 6.62 s
# Early stopping at epoch 126
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.88%, Val MAPE: 0.98%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.12%, D: 0.90%, H: 1.01%
# 10.43 s
# Early stopping at epoch 84
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.95%, Val MAPE: 1.00%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.03%, D: 0.97%, H: 0.79%
# 7.42 s
# Early stopping at epoch 94
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.64%, Val MAPE: 1.52%, Test MAPE: 1.71%
# Test MAPE by 'Next': M: 1.92%, D: 1.17%, H: 2.03%
# 7.72 s
# Early stopping at epoch 81
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.87%, Val MAPE: 0.81%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 1.02%, D: 0.82%, H: 0.80%
# 5.62 s
# Early stopping at epoch 120
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.31%, Val MAPE: 1.26%, Test MAPE: 1.22%
# Test MAPE by 'Next': M: 1.20%, D: 1.12%, H: 1.32%
# 8.58 s
# Early stopping at epoch 75
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.87%, Test MAPE: 0.82%
# Test MAPE by 'Next': M: 0.87%, D: 0.80%, H: 0.78%
# 5.83 s
# Early stopping at epoch 156
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.29%, Val MAPE: 1.16%, Test MAPE: 1.38%
# Test MAPE by 'Next': M: 1.61%, D: 1.20%, H: 1.33%
# 12.74 s
# Early stopping at epoch 118
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.85%, Test MAPE: 0.81%
# Test MAPE by 'Next': M: 0.86%, D: 0.79%, H: 0.77%
# 9.82 s
# Early stopping at epoch 128
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.94%, Val MAPE: 1.02%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.27%, D: 0.76%, H: 0.98%
# 10.07 s
# Early stopping at epoch 94
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.15%, Val MAPE: 1.23%, Test MAPE: 1.10%
# Test MAPE by 'Next': M: 1.09%, D: 1.23%, H: 0.99%
# 7.35 s
# Early stopping at epoch 85
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.17%, Val MAPE: 1.20%, Test MAPE: 1.07%
# Test MAPE by 'Next': M: 1.45%, D: 0.80%, H: 0.95%
# 7.18 s
# Early stopping at epoch 96
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.93%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.90%, D: 0.84%, H: 0.82%
# 8.62 s
# Early stopping at epoch 101
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.27%, Val MAPE: 1.27%, Test MAPE: 1.15%
# Test MAPE by 'Next': M: 1.08%, D: 1.35%, H: 1.03%
# 9.79 s
# Early stopping at epoch 200
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.89%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.95%, D: 1.79%, H: 1.73%
# 16.36 s
# Early stopping at epoch 61
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.85%, Val MAPE: 1.86%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.92%, D: 1.78%, H: 1.74%
# 5.15 s
# Early stopping at epoch 88
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.88%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 0.98%, D: 0.82%, H: 0.96%
# 7.18 s
# Early stopping at epoch 138
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.78%, Val MAPE: 0.83%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.94%, D: 0.84%, H: 0.80%
# 11.21 s
# Early stopping at epoch 120
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.89%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 10.69 s
# Early stopping at epoch 94
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.82%, Val MAPE: 1.88%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.94%, D: 1.79%, H: 1.72%
# 8.44 s
# Early stopping at epoch 196
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.01%, Val MAPE: 0.95%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.05%, D: 1.02%, H: 1.12%
# 16.55 s
# Early stopping at epoch 153
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.04%, Val MAPE: 1.03%, Test MAPE: 1.17%
# Test MAPE by 'Next': M: 1.22%, D: 1.08%, H: 1.22%
# 12.36 s
# Early stopping at epoch 213
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.82%, Val MAPE: 0.86%, Test MAPE: 0.82%
# Test MAPE by 'Next': M: 0.92%, D: 0.84%, H: 0.71%
# 17.04 s
# Early stopping at epoch 129
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.38%, Val MAPE: 1.26%, Test MAPE: 1.46%
# Test MAPE by 'Next': M: 1.20%, D: 1.96%, H: 1.23%
# 10.44 s
# Early stopping at epoch 73
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.87%, Val MAPE: 0.91%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.90%, D: 0.92%, H: 0.81%
# 6.63 s
# Early stopping at epoch 121
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.06%, Val MAPE: 0.98%, Test MAPE: 1.09%
# Test MAPE by 'Next': M: 0.99%, D: 1.58%, H: 0.69%
# 10.61 s
# Early stopping at epoch 273
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.03%, Val MAPE: 0.98%, Test MAPE: 1.09%
# Test MAPE by 'Next': M: 1.17%, D: 0.88%, H: 1.21%
# 22.08 s
# Early stopping at epoch 89
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.93%, Val MAPE: 0.77%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.04%, D: 0.93%, H: 0.84%
# 7.25 s
# Early stopping at epoch 78
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.90%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.90%, D: 0.81%, H: 0.85%
# 6.03 s
# Early stopping at epoch 101
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.99%, Val MAPE: 1.89%, Test MAPE: 2.12%
# Test MAPE by 'Next': M: 2.25%, D: 1.46%, H: 2.64%
# 8.13 s
# Early stopping at epoch 81
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.91%, Val MAPE: 0.84%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.00%, D: 0.84%, H: 0.99%
# 6.78 s
# Early stopping at epoch 167
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.84%, Val MAPE: 0.90%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.94%, D: 0.99%, H: 0.78%
# 15.11 s
# Early stopping at epoch 169
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 15.77 s
# Early stopping at epoch 58
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 4.83 s
# Early stopping at epoch 84
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.94%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.88%, D: 0.83%, H: 0.82%
# 6.49 s
# Early stopping at epoch 220
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.42%, Val MAPE: 1.27%, Test MAPE: 1.48%
# Test MAPE by 'Next': M: 1.06%, D: 1.39%, H: 1.99%
# 17.23 s
# Early stopping at epoch 159
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.90%, Val MAPE: 0.91%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.09%, D: 0.81%, H: 0.98%
# 14.03 s
# Early stopping at epoch 148
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.90%, Val MAPE: 0.92%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.95%, D: 0.83%, H: 0.79%
# 13.33 s
# Early stopping at epoch 150
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.92%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.87%, D: 0.85%, H: 0.82%
# 15.10 s
# Early stopping at epoch 110
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 0.87%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.03%, D: 0.82%, H: 0.92%
# 11.06 s
# Early stopping at epoch 131
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.87%, Val MAPE: 0.89%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.93%, D: 0.84%, H: 0.91%
# 9.26 s
# Early stopping at epoch 121
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.90%, Val MAPE: 0.98%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 0.90%, D: 0.78%, H: 1.18%
# 8.46 s
# Early stopping at epoch 66
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.88%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.88%, D: 0.90%, H: 0.76%
# 4.89 s
# Early stopping at epoch 131
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.05%, Val MAPE: 0.91%, Test MAPE: 1.08%
# Test MAPE by 'Next': M: 1.12%, D: 1.06%, H: 1.05%
# 9.64 s
# Early stopping at epoch 112
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.85%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.05%, D: 0.84%, H: 0.93%
# 8.57 s
# Early stopping at epoch 139
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 2.44%, Val MAPE: 2.50%, Test MAPE: 2.35%
# Test MAPE by 'Next': M: 2.28%, D: 2.65%, H: 2.13%
# 10.56 s
# Early stopping at epoch 75
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.92%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.89%, D: 0.79%, H: 0.86%
# 5.29 s
# Early stopping at epoch 57
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.81%, Val MAPE: 0.98%, Test MAPE: 0.83%
# Test MAPE by 'Next': M: 0.87%, D: 0.82%, H: 0.80%
# 4.04 s
# Early stopping at epoch 110
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.97%, Val MAPE: 0.94%, Test MAPE: 1.02%
# Test MAPE by 'Next': M: 1.15%, D: 0.89%, H: 1.02%
# 8.02 s
# Early stopping at epoch 71
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.44%, Val MAPE: 1.48%, Test MAPE: 1.35%
# Test MAPE by 'Next': M: 1.08%, D: 1.89%, H: 1.08%
# 5.27 s
# Early stopping at epoch 161
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.83%, Val MAPE: 1.93%, Test MAPE: 1.84%
# Test MAPE by 'Next': M: 1.98%, D: 1.81%, H: 1.74%
# 12.21 s
# Early stopping at epoch 80
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.92%, Val MAPE: 1.90%, Test MAPE: 1.85%
# Test MAPE by 'Next': M: 1.93%, D: 1.79%, H: 1.83%
# 6.14 s
# Early stopping at epoch 103
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.89%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.90%, D: 0.82%, H: 0.94%
# 7.15 s
# Early stopping at epoch 147
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 0.87%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.98%, D: 0.85%, H: 0.91%
# 10.35 s
# Early stopping at epoch 94
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.87%, Val MAPE: 0.86%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.95%, D: 0.82%, H: 0.95%
# 6.84 s
# Early stopping at epoch 60
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.18%, Val MAPE: 1.11%, Test MAPE: 1.20%
# Test MAPE by 'Next': M: 1.11%, D: 1.03%, H: 1.45%
# 4.39 s
# Early stopping at epoch 82
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.88%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.92%, D: 0.82%, H: 0.96%
# 6.27 s
# Early stopping at epoch 271
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.33%, Val MAPE: 1.20%, Test MAPE: 1.46%
# Test MAPE by 'Next': M: 1.64%, D: 1.20%, H: 1.53%
# 20.63 s
# Early stopping at epoch 65
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.93%, Val MAPE: 1.06%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.01%, D: 0.95%, H: 0.80%
# 4.65 s
# Early stopping at epoch 121
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.87%, Val MAPE: 0.89%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.45%, D: 0.84%, H: 0.75%
# 8.45 s
# Early stopping at epoch 84
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.93%, Val MAPE: 0.88%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.02%, D: 0.91%, H: 0.92%
# 6.21 s
# Early stopping at epoch 85
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 2.92%, Val MAPE: 2.86%, Test MAPE: 3.08%
# Test MAPE by 'Next': M: 3.26%, D: 3.73%, H: 2.25%
# 6.27 s
# Early stopping at epoch 127
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.90%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.92%, D: 0.86%, H: 0.77%
# 9.69 s
# Early stopping at epoch 107
# Model: GRU, rs: 100, rnn_hid: 4, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.56%, Val MAPE: 1.59%, Test MAPE: 1.46%
# Test MAPE by 'Next': M: 1.49%, D: 1.67%, H: 1.22%
# 8.32 s
# Early stopping at epoch 180
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.92%, Val MAPE: 1.06%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 0.91%, D: 0.88%, H: 1.02%
# 10.50 s
# Early stopping at epoch 69
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 2.13%, Val MAPE: 2.09%, Test MAPE: 2.28%
# Test MAPE by 'Next': M: 2.28%, D: 2.13%, H: 2.42%
# 4.07 s
# Early stopping at epoch 112
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.89%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 7.02 s
# Early stopping at epoch 76
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.82%, Val MAPE: 1.89%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.79%, H: 1.73%
# 4.78 s
# Early stopping at epoch 149
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 9.83 s
# Early stopping at epoch 85
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 2.00%, Val MAPE: 2.16%, Test MAPE: 2.02%
# Test MAPE by 'Next': M: 2.20%, D: 2.00%, H: 1.87%
# 5.68 s
# Early stopping at epoch 74
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.92%, Val MAPE: 1.05%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.04%, D: 0.94%, H: 0.85%
# 4.41 s
# Early stopping at epoch 129
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.20%, Val MAPE: 1.28%, Test MAPE: 1.38%
# Test MAPE by 'Next': M: 2.05%, D: 0.87%, H: 1.22%
# 7.65 s
# Early stopping at epoch 75
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.91%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.94%, D: 0.83%, H: 0.82%
# 4.80 s
# Early stopping at epoch 138
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.75%, Val MAPE: 0.82%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 1.11%, D: 0.77%, H: 0.82%
# 8.58 s
# Early stopping at epoch 84
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.04%, Val MAPE: 1.16%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.08%, D: 1.10%, H: 0.95%
# 5.54 s
# Early stopping at epoch 99
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.85%, Val MAPE: 1.00%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.13%, D: 0.94%, H: 0.78%
# 6.65 s
# Early stopping at epoch 93
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.91%, Val MAPE: 1.12%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.02%, D: 1.04%, H: 0.90%
# 5.54 s
# Early stopping at epoch 117
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.00%, Val MAPE: 0.92%, Test MAPE: 1.08%
# Test MAPE by 'Next': M: 0.99%, D: 0.95%, H: 1.31%
# 6.94 s
# Early stopping at epoch 76
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.91%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.95%, D: 0.91%, H: 0.86%
# 4.81 s
# Early stopping at epoch 127
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.24%, Val MAPE: 1.10%, Test MAPE: 1.32%
# Test MAPE by 'Next': M: 1.42%, D: 1.01%, H: 1.52%
# 8.00 s
# Early stopping at epoch 74
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.87%, Val MAPE: 0.92%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.02%, D: 0.90%, H: 0.80%
# 4.99 s
# Early stopping at epoch 123
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 0.76%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.05%, D: 0.86%, H: 0.89%
# 8.22 s
# Early stopping at epoch 95
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.90%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.97%, D: 0.81%, H: 0.92%
# 5.64 s
# Early stopping at epoch 119
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.36%, Val MAPE: 1.27%, Test MAPE: 1.49%
# Test MAPE by 'Next': M: 1.72%, D: 1.15%, H: 1.60%
# 7.06 s
# Early stopping at epoch 89
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.97%, Val MAPE: 1.03%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 0.95%, D: 0.98%, H: 0.94%
# 5.65 s
# Early stopping at epoch 65
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.96%, Val MAPE: 1.01%, Test MAPE: 1.08%
# Test MAPE by 'Next': M: 1.20%, D: 1.04%, H: 1.01%
# 4.26 s
# Early stopping at epoch 118
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.88%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.94%, D: 1.79%, H: 1.72%
# 7.74 s
# Early stopping at epoch 80
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 2.03%, Val MAPE: 1.99%, Test MAPE: 1.94%
# Test MAPE by 'Next': M: 1.98%, D: 1.87%, H: 1.99%
# 5.28 s
# Early stopping at epoch 78
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.17%, Val MAPE: 1.16%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 0.95%, D: 0.99%, H: 1.38%
# 4.65 s
# Early stopping at epoch 64
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 2.11%, Val MAPE: 2.11%, Test MAPE: 2.04%
# Test MAPE by 'Next': M: 2.10%, D: 2.12%, H: 1.91%
# 3.82 s
# Early stopping at epoch 86
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.90%, Val MAPE: 1.09%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.01%, D: 0.98%, H: 0.86%
# 5.39 s
# Early stopping at epoch 127
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.07%, Val MAPE: 1.08%, Test MAPE: 1.09%
# Test MAPE by 'Next': M: 1.13%, D: 1.27%, H: 0.87%
# 7.96 s
# Early stopping at epoch 105
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.04%, Val MAPE: 0.87%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.15%, D: 0.95%, H: 1.21%
# 6.93 s
# Early stopping at epoch 70
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.87%, Val MAPE: 0.91%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.12%, D: 0.80%, H: 1.10%
# 4.71 s
# Early stopping at epoch 93
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.08%, Val MAPE: 1.16%, Test MAPE: 1.28%
# Test MAPE by 'Next': M: 1.36%, D: 0.98%, H: 1.51%
# 5.48 s
# Early stopping at epoch 59
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.00%, Val MAPE: 1.13%, Test MAPE: 1.14%
# Test MAPE by 'Next': M: 1.05%, D: 0.85%, H: 1.53%
# 3.58 s
# Early stopping at epoch 66
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.96%, Val MAPE: 0.91%, Test MAPE: 1.02%
# Test MAPE by 'Next': M: 1.15%, D: 0.91%, H: 1.00%
# 4.26 s
# Early stopping at epoch 191
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.75%, Val MAPE: 0.98%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.94%, D: 0.93%, H: 0.69%
# 12.13 s
# Early stopping at epoch 74
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.86%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.95%, D: 0.90%, H: 0.79%
# 4.91 s
# Early stopping at epoch 81
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.82%, Val MAPE: 0.82%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.04%, D: 0.85%, H: 0.88%
# 5.40 s
# Early stopping at epoch 101
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 1.04%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.94%, D: 0.85%, H: 0.91%
# 5.99 s
# Early stopping at epoch 171
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.45%, Val MAPE: 1.51%, Test MAPE: 1.38%
# Test MAPE by 'Next': M: 1.23%, D: 1.87%, H: 1.03%
# 10.13 s
# Early stopping at epoch 110
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.99%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.94%, D: 0.89%, H: 0.84%
# 7.02 s
# Early stopping at epoch 97
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.90%, Val MAPE: 1.14%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.15%, D: 0.98%, H: 0.98%
# 6.09 s
# Early stopping at epoch 109
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.91%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.97%, D: 1.80%, H: 1.73%
# 7.30 s
# Early stopping at epoch 58
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.87%, Val MAPE: 1.87%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.93%, D: 1.77%, H: 1.77%
# 3.91 s
# Early stopping at epoch 66
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.82%, Val MAPE: 0.91%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.99%, D: 0.83%, H: 0.92%
# 3.95 s
# Early stopping at epoch 87
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.19%, Val MAPE: 1.27%, Test MAPE: 1.20%
# Test MAPE by 'Next': M: 1.35%, D: 1.27%, H: 0.97%
# 5.20 s
# Early stopping at epoch 78
# Model: GRU, rs: 100, rnn_hid: 8, rnn_layer: 1, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.89%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.93%, D: 0.82%, H: 0.85%
# 4.96 s
# Early stopping at epoch 104
# ...
#  Train MAPE: 0.77%, Val MAPE: 0.83%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.01%, D: 0.84%, H: 0.91%
# 7.03 s
# Early stopping at epoch 142
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.92%, Test MAPE: 1.10%
# Test MAPE by 'Next': M: 1.03%, D: 1.27%, H: 0.98%
# 10.41 s
# Early stopping at epoch 63
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.78%, Val MAPE: 1.76%, Test MAPE: 1.95%
# Test MAPE by 'Next': M: 2.04%, D: 1.73%, H: 2.08%
# 4.66 s
# Early stopping at epoch 166
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.98%, Val MAPE: 1.03%, Test MAPE: 1.15%
# Test MAPE by 'Next': M: 1.27%, D: 1.18%, H: 1.01%
# 10.88 s
# Early stopping at epoch 185
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.51%, Val MAPE: 1.62%, Test MAPE: 1.79%
# Test MAPE by 'Next': M: 1.71%, D: 1.92%, H: 1.73%
# 12.24 s
# Early stopping at epoch 273
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.95%, Test MAPE: 1.10%
# Test MAPE by 'Next': M: 0.99%, D: 1.20%, H: 1.12%
# 18.78 s
# Early stopping at epoch 184
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.72%, Val MAPE: 0.96%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.87%, D: 0.77%, H: 0.96%
# 12.73 s
# Early stopping at epoch 96
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 0.93%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.04%, D: 0.93%, H: 0.90%
# 6.79 s
# Early stopping at epoch 132
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.43%, Val MAPE: 1.61%, Test MAPE: 1.43%
# Test MAPE by 'Next': M: 1.37%, D: 1.36%, H: 1.57%
# 9.39 s
# Early stopping at epoch 131
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.31%, Val MAPE: 1.28%, Test MAPE: 1.58%
# Test MAPE by 'Next': M: 1.50%, D: 1.56%, H: 1.68%
# 8.70 s
# Early stopping at epoch 118
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.44%, Val MAPE: 1.53%, Test MAPE: 1.34%
# Test MAPE by 'Next': M: 1.31%, D: 1.35%, H: 1.35%
# 7.88 s
# Early stopping at epoch 74
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.04%, Val MAPE: 1.18%, Test MAPE: 1.21%
# Test MAPE by 'Next': M: 1.40%, D: 1.24%, H: 0.98%
# 5.27 s
# Early stopping at epoch 142
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.13%, Val MAPE: 1.38%, Test MAPE: 1.33%
# Test MAPE by 'Next': M: 1.28%, D: 1.48%, H: 1.22%
# 9.95 s
# Early stopping at epoch 113
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.93%, Val MAPE: 1.05%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.05%, D: 0.89%, H: 0.89%
# 8.27 s
# Early stopping at epoch 173
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 2, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.73%, Val MAPE: 0.87%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.92%, D: 0.87%, H: 0.88%
# 12.49 s
# Early stopping at epoch 119
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.89%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.09%, D: 1.07%, H: 0.97%
# 8.70 s
# Early stopping at epoch 157
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.90%, Val MAPE: 0.98%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.01%, D: 1.09%, H: 1.05%
# 11.30 s
# Early stopping at epoch 164
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.18%, Val MAPE: 1.22%, Test MAPE: 1.26%
# Test MAPE by 'Next': M: 1.32%, D: 1.15%, H: 1.31%
# 12.21 s
# Early stopping at epoch 80
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 3.49%, Val MAPE: 3.62%, Test MAPE: 4.44%
# Test MAPE by 'Next': M: 3.47%, D: 5.06%, H: 4.79%
# 6.03 s
# Early stopping at epoch 134
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.99%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 0.99%, D: 1.12%, H: 1.06%
# 10.39 s
# Early stopping at epoch 114
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.22%, Val MAPE: 1.26%, Test MAPE: 1.19%
# Test MAPE by 'Next': M: 1.29%, D: 1.06%, H: 1.23%
# 8.71 s
# Early stopping at epoch 124
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 1.07%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.10%, D: 1.02%, H: 1.00%
# 8.70 s
# Early stopping at epoch 80
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.30%, Val MAPE: 1.45%, Test MAPE: 1.41%
# Test MAPE by 'Next': M: 1.25%, D: 1.80%, H: 1.17%
# 5.67 s
# Early stopping at epoch 128
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.94%, Test MAPE: 1.27%
# Test MAPE by 'Next': M: 1.11%, D: 1.50%, H: 1.20%
# 9.29 s
# Early stopping at epoch 174
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.77%, Val MAPE: 0.94%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 0.93%, D: 1.01%, H: 0.87%
# 12.53 s
# Early stopping at epoch 142
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.74%, Val MAPE: 0.89%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.07%, D: 1.08%, H: 1.18%
# 10.82 s
# Early stopping at epoch 105
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 0.95%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.08%, D: 1.11%, H: 0.94%
# 8.01 s
# Early stopping at epoch 190
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.82%, Val MAPE: 1.01%, Test MAPE: 1.31%
# Test MAPE by 'Next': M: 1.02%, D: 1.65%, H: 1.26%
# 13.17 s
# Early stopping at epoch 144
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.75%, Val MAPE: 0.85%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.09%, D: 0.86%, H: 0.87%
# 10.08 s
# Early stopping at epoch 128
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.92%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.09%, D: 0.93%, H: 1.13%
# 9.35 s
# Early stopping at epoch 113
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.73%, Val MAPE: 0.83%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.05%, D: 0.85%, H: 0.87%
# 8.32 s
# Early stopping at epoch 98
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.90%, Test MAPE: 0.98%
# Test MAPE by 'Next': M: 0.98%, D: 1.06%, H: 0.90%
# 7.45 s
# Early stopping at epoch 141
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 2, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.71%, Val MAPE: 0.88%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.98%, D: 0.86%, H: 0.83%
# 10.74 s
# Early stopping at epoch 122
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.30%, Val MAPE: 1.32%, Test MAPE: 1.57%
# Test MAPE by 'Next': M: 1.52%, D: 1.74%, H: 1.45%
# 8.47 s
# Early stopping at epoch 144
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.93%, Val MAPE: 1.02%, Test MAPE: 1.16%
# Test MAPE by 'Next': M: 1.10%, D: 1.20%, H: 1.17%
# 10.10 s
# Early stopping at epoch 74
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 1.10%, Val MAPE: 1.31%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.17%, D: 1.00%, H: 1.00%
# 5.48 s
# Early stopping at epoch 129
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.83%, Val MAPE: 0.91%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 0.95%, D: 1.14%, H: 0.89%
# 9.50 s
# Early stopping at epoch 139
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.90%, Val MAPE: 0.97%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.04%, D: 1.05%, H: 0.91%
# 10.60 s
# Early stopping at epoch 229
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.82%, Val MAPE: 0.94%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 0.90%, D: 0.99%, H: 0.97%
# 17.30 s
# Early stopping at epoch 121
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 1.07%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.10%, D: 1.05%, H: 0.99%
# 8.68 s
# Early stopping at epoch 155
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.96%, Val MAPE: 1.08%, Test MAPE: 1.16%
# Test MAPE by 'Next': M: 1.34%, D: 1.12%, H: 1.01%
# 11.44 s
# Early stopping at epoch 120
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.77%, Val MAPE: 0.84%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 0.98%, D: 1.25%, H: 1.09%
# 9.13 s
# Early stopping at epoch 194
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.09%, Val MAPE: 1.15%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.26%, D: 1.11%, H: 0.83%
# 14.36 s
# Early stopping at epoch 86
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.90%, Test MAPE: 1.13%
# Test MAPE by 'Next': M: 0.97%, D: 1.30%, H: 1.13%
# 6.66 s
# Early stopping at epoch 202
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.82%, Val MAPE: 0.88%, Test MAPE: 0.97%
# Test MAPE by 'Next': M: 0.99%, D: 0.90%, H: 1.02%
# 15.40 s
# Early stopping at epoch 182
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.06%, Val MAPE: 1.27%, Test MAPE: 1.47%
# Test MAPE by 'Next': M: 1.24%, D: 1.52%, H: 1.65%
# 12.62 s
# Early stopping at epoch 149
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 2.19%, Val MAPE: 2.24%, Test MAPE: 2.39%
# Test MAPE by 'Next': M: 2.13%, D: 2.22%, H: 2.82%
# 10.71 s
# Early stopping at epoch 81
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.92%, Val MAPE: 1.05%, Test MAPE: 1.12%
# Test MAPE by 'Next': M: 1.25%, D: 1.13%, H: 0.99%
# 6.12 s
# Early stopping at epoch 146
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 2.36%, Val MAPE: 2.28%, Test MAPE: 2.16%
# Test MAPE by 'Next': M: 2.27%, D: 2.23%, H: 1.98%
# 10.72 s
# Early stopping at epoch 162
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.93%, Test MAPE: 1.53%
# Test MAPE by 'Next': M: 1.17%, D: 1.82%, H: 1.61%
# 12.38 s
# Early stopping at epoch 143
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 4, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.43%, Val MAPE: 1.49%, Test MAPE: 1.42%
# Test MAPE by 'Next': M: 1.43%, D: 1.32%, H: 1.52%
# 11.07 s
# Early stopping at epoch 108
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.88%, Test MAPE: 1.10%
# Test MAPE by 'Next': M: 0.97%, D: 1.22%, H: 1.10%
# 7.80 s
# Early stopping at epoch 204
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.75%, Val MAPE: 0.85%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.98%, D: 0.88%, H: 0.82%
# 14.64 s
# Early stopping at epoch 97
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.74%, Val MAPE: 0.86%, Test MAPE: 1.09%
# Test MAPE by 'Next': M: 1.01%, D: 1.16%, H: 1.09%
# 7.27 s
# Early stopping at epoch 290
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.05%, Val MAPE: 1.20%, Test MAPE: 1.25%
# Test MAPE by 'Next': M: 1.23%, D: 1.28%, H: 1.25%
# 21.33 s
# Early stopping at epoch 114
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.001
#  Train MAPE: 1.78%, Val MAPE: 1.73%, Test MAPE: 1.94%
# Test MAPE by 'Next': M: 2.00%, D: 1.72%, H: 2.10%
# 8.82 s
# Early stopping at epoch 62
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 4, fc_layer: 3, lr: 0.01
#  Train MAPE: 1.82%, Val MAPE: 1.84%, Test MAPE: 2.00%
# Test MAPE by 'Next': M: 2.11%, D: 1.77%, H: 2.10%
# 4.81 s
# Early stopping at epoch 75
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.98%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.11%, D: 1.02%, H: 0.88%
# 5.54 s
# Early stopping at epoch 89
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 1, lr: 0.01
#  Train MAPE: 1.42%, Val MAPE: 1.55%, Test MAPE: 1.67%
# Test MAPE by 'Next': M: 1.56%, D: 1.70%, H: 1.74%
# 6.58 s
# Early stopping at epoch 83
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.98%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 0.96%, D: 1.11%, H: 0.94%
# 6.27 s
# Early stopping at epoch 106
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 2, lr: 0.01
#  Train MAPE: 1.31%, Val MAPE: 1.33%, Test MAPE: 1.41%
# Test MAPE by 'Next': M: 1.42%, D: 1.56%, H: 1.25%
# 8.02 s
# Early stopping at epoch 161
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.78%, Val MAPE: 0.84%, Test MAPE: 1.14%
# Test MAPE by 'Next': M: 1.07%, D: 1.22%, H: 1.12%
# 12.48 s
# Early stopping at epoch 270
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 8, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.71%, Val MAPE: 0.88%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.94%, D: 0.91%, H: 0.74%
# 20.80 s
# Early stopping at epoch 77
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.79%, Test MAPE: 2.09%
# Test MAPE by 'Next': M: 2.18%, D: 2.21%, H: 1.88%
# 5.69 s
# Early stopping at epoch 176
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 1, lr: 0.01
#  Train MAPE: 0.95%, Val MAPE: 0.92%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 0.88%, D: 0.94%, H: 1.30%
# 12.91 s
# Early stopping at epoch 186
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.001
#  Train MAPE: 0.74%, Val MAPE: 0.88%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.01%, D: 1.04%, H: 0.94%
# 13.80 s
# Early stopping at epoch 139
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 2, lr: 0.01
#  Train MAPE: 0.85%, Val MAPE: 0.90%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 0.89%, D: 0.95%, H: 1.29%
# 10.40 s
# Early stopping at epoch 160
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 0.83%, Test MAPE: 1.13%
# Test MAPE by 'Next': M: 0.98%, D: 1.31%, H: 1.10%
# 12.23 s
# Early stopping at epoch 150
# Model: GRU, rs: 180, rnn_hid: 32, rnn_layer: 3, rnn_out: 8, fc_hid: 16, fc_layer: 3, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 1.07%, Test MAPE: 1.07%
# Test MAPE by 'Next': M: 1.10%, D: 1.24%, H: 0.88%
# 11.46 s

# %%
summary_df = results_df.groupby(['rnn_hids', 'rnn_layers', 'rnn_outs', 'fc_hids', 'fc_layers', 'lrs'])[['Train MAPE', 'Val MAPE', 'Test MAPE', 'Next M MAPE', 'Next D MAPE', 'Next H MAPE']].mean().reset_index()
summary_df
summary_df.to_csv('GRU_Processed_next_info_sum.csv')
results_df.to_csv('GRU_Processed_next_info.csv')
# Out:
#      rnn_hids  rnn_layers  rnn_outs  fc_hids  fc_layers    lrs  Train MAPE  \
# 0         4.0         1.0       2.0      4.0        1.0  0.001    1.048130
# 1         4.0         1.0       2.0      4.0        1.0  0.010    1.157239
# 2         4.0         1.0       2.0      4.0        2.0  0.001    0.968489
# 3         4.0         1.0       2.0      4.0        2.0  0.010    0.939854
# 4         4.0         1.0       2.0      4.0        3.0  0.001    1.037154
# ..        ...         ...       ...      ...        ...    ...         ...
# 643      32.0         3.0       8.0     16.0        1.0  0.010    1.148304
# 644      32.0         3.0       8.0     16.0        2.0  0.001    0.974105
# 645      32.0         3.0       8.0     16.0        2.0  0.010    1.159377
# 646      32.0         3.0       8.0     16.0        3.0  0.001    0.913995
# 647      32.0         3.0       8.0     16.0        3.0  0.010    0.919532
#
#      Val MAPE  Test MAPE  Next M MAPE  Next D MAPE  Next H MAPE
# 0    1.083924   1.035548     1.093587     0.977927     1.035129
# 1    1.168175   1.153326     1.163812     1.092868     1.203298
# 2    1.012847   1.003763     1.101455     0.898456     1.011378
# 3    0.952547   0.960346     0.988768     0.943731     0.948538
# 4    1.097210   1.079946     1.131331     1.023151     1.085356
# ..        ...        ...          ...          ...          ...
# 643  1.188572   1.193966     1.209776     1.074674     1.297447
# 644  1.071653   1.000153     1.087183     1.021262     0.892014
# 645  1.209776   1.271593     1.286642     1.150500     1.377638
# 646  0.957944   0.927618     0.958275     0.990044     0.834535
# 647  1.019151   0.946873     0.943899     1.010515     0.886204
#
# [648 rows x 12 columns]
