# %%
import pandas as pd
import numpy as np
import random
import os
import time
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
import time

from numpy import hstack, vstack
import itertools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from itertools import product

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

from torch.utils.data import DataLoader, TensorDataset

import warnings
warnings.filterwarnings(action='ignore')

# %%
def find_directory(foldername, filename = None, back_num = 0):
    cur = os.getcwd()
    for i in range(back_num):
        cur = os.path.abspath(os.path.join(cur, os.pardir))
    for folder in foldername:
        cur = os.path.join(cur, folder)
    if not os.path.exists(cur):
        os.makedirs(cur)
        print(f'{cur} created')
    if filename != None:
        cur = os.path.join(cur, filename)
    return cur

os.getcwd()
# Out:
# 'c:\\Users\\dkstj\\Desktop\\연구\\현대차 3차\\Rapid_fin\\deep learning modeling'

# %%
csv_add = find_directory(foldername = [], filename = 'SOC_Point_Data.csv')
dat = pd.read_csv(csv_add, index_col = (0,1,2,3,4))

# %%
def Get_Data(dat) :
    
    RPT_MODE = "0.1C"
    SOC_Range = [9,10,11,12]

    Time_Range = range(6, 15, 2)
    SOC_Range = [str(i) for i in SOC_Range]
    

    Data = dat

    X = Data.loc[RPT_MODE, "0" : "16"]
    Y = Data.loc[RPT_MODE, ["SOH", "Next_SOH", "Ratio_SOH", "Ratio_CYC"]].groupby(level = ["Next", "Path", "Number"]).mean()
    
    y = pd.Series(Y["Next_SOH"] - Y["SOH"], name = "Delta_SOH")
    
    Y = pd.concat([Y, y], axis = 1)

    X_seek = X.loc[X.index.get_level_values("Time").isin(Time_Range), SOC_Range]


    X_std = X_seek.groupby(level = ["Next", "Path", "Number"]).std()
    
    return X_std, Y

# %%
def Even_Split(X, y, test_size, rs) :

    X_M = X.xs(key = 'M', level = 'Next', drop_level = False)
    X_D = X.xs(key = 'D', level = 'Next', drop_level = False)
    X_H = X.xs(key = 'H', level = 'Next', drop_level = False)
    
    XX = {"M" : X_M, "D" : X_D, "H" : X_H}
    
    y_M = y.xs(key = 'M', level = 'Next', drop_level = False)
    y_D = y.xs(key = 'D', level = 'Next', drop_level = False)
    y_H = y.xs(key = 'H', level = 'Next', drop_level = False)
    
    yy = {"M" : y_M, "D" : y_D, "H" : y_H}
    
    
    XXX = {"M" : [], "D" : [], "H" : []}
    
    yyy = {"M" : [], "D" : [], "H" : []}
    
    
    for n in ["M", "D", "H"] :
        for path in range(1,5) :
            X_path = XX[n].loc[XX[n].index.get_level_values(level = 'Path').str.len() == path]
            y_path = yy[n].loc[yy[n].index.get_level_values(level = 'Path').str.len() == path]
            
            XXX[n].append(X_path)
            yyy[n].append(y_path)
            
            
    XX_tn = {"M" : [], "D" : [], "H" : []}
    XX_te = {"M" : [], "D" : [], "H" : []}
    
    yy_tn = {"M" : [], "D" : [], "H" : []}
    yy_te = {"M" : [], "D" : [], "H" : []}
        
    for n in ["M", "D", "H"] :
        for path in range(1,5) :
            X_temp = XXX[n][path-1]
            y_temp = yyy[n][path-1]
            
            X_tn, X_te, y_tn, y_te = train_test_split(X_temp, y_temp, test_size = test_size, random_state = rs)
            
            XX_tn[n].append(X_tn)
            XX_te[n].append(X_te)
            yy_tn[n].append(y_tn)
            yy_te[n].append(y_te)
                  
    for n in ["M", "D", "H"] :
        XX_tn[n] = pd.concat(XX_tn[n])
        XX_te[n] = pd.concat(XX_te[n])
        yy_tn[n] = pd.concat(yy_tn[n])
        yy_te[n] = pd.concat(yy_te[n])
        
        
    X_tn = pd.concat(XX_tn.values())
    X_te = pd.concat(XX_te.values())
    
    y_tn = pd.concat(yy_tn.values())
    y_te = pd.concat(yy_te.values())
    
    return X_tn, X_te, y_tn, y_te

# %%
def convert_to_tensor(X_tn, X_te, y_tn, y_te, batch_size=32, val_size=0.2, rs=100):
    """
    X_tn, X_te: MultiIndex DataFrame (Next, Path, Number, Time)
    y_tn, y_te: Series or DataFrame with index (Next, Path, Number)
    """

    X_tr, X_vl, y_tr, y_vl = Even_Split(X_tn, y_tn, val_size, rs)
    keys_train = y_tr.index
    keys_val = y_vl.index

    scaler = StandardScaler()
    X_tn_scaled = X_tn.copy()
    X_te_scaled = X_te.copy()

    scaler.fit(X_tn.values)
    X_tn_scaled.loc[:, :] = scaler.transform(X_tn.values)
    X_te_scaled.loc[:, :] = scaler.transform(X_te.values)

    next_map = {'M': 0, 'D': 1, 'H': 2}
    get_next = lambda idx: torch.nn.functional.one_hot(torch.tensor([next_map[i] for i in idx.get_level_values("Next")]), num_classes=3).float()

    def to_tensor(X_df, y_df, keys):
        X_group = X_df.groupby(level=["Next", "Path", "Number"])
        X_tensor = torch.stack([
            torch.tensor(X_group.get_group(k).values.T, dtype=torch.float32)
            for k in keys
        ])
        y_tensor = torch.tensor(y_df.loc[keys].values, dtype=torch.float32).unsqueeze(1)
        return X_tensor, y_tensor

    next_train = get_next(pd.MultiIndex.from_tuples(keys_train, names=["Next", "Path", "Number"]))
    next_val   = get_next(pd.MultiIndex.from_tuples(keys_val,   names=["Next", "Path", "Number"]))
    next_test  = get_next(y_te.index)
    
    X_train_tensor, y_train_tensor = to_tensor(X_tn_scaled, y_tn, keys_train)
    X_val_tensor,   y_val_tensor   = to_tensor(X_tn_scaled, y_tn, keys_val)
    X_test_tensor,  y_test_tensor  = to_tensor(X_te_scaled, y_te, y_te.index.drop_duplicates())

    train_loader = DataLoader(TensorDataset(X_train_tensor, next_train, y_train_tensor), batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(TensorDataset(X_val_tensor, next_val,  y_val_tensor),   batch_size=batch_size, shuffle=False)
    test_loader  = DataLoader(TensorDataset(X_test_tensor, next_test,  y_test_tensor),  batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader, X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor, X_test_tensor, y_test_tensor, scaler

# %%
def setRandomSeed(random_seed=0):
    os.environ['PYTHONHASHSEED'] = str(random_seed)
    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(random_seed)
    random.seed(random_seed)

# %%
class Trainer:
    def __init__(self, model, lr=1e-3, weight_decay=0, epoch=1000, patience=50, random_seed = 0):
        self.random_seed = random_seed
        #setRandomSeed(self.random_seed)
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.model = model.to(self.device)
        self.criterion = nn.MSELoss()
        self.cri2 = MAPELoss()
        self.optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        self.scheduler = torch.optim.lr_scheduler.StepLR(self.optimizer, step_size=200, gamma=0.8)
        self.epoch = epoch
        self.patience = patience

        self.train_loss = []
        self.test_loss = []
        self.val_loss = []

    def train(self, train_loader, test_loader=None, val_loader=None):
        best_val_loss = float('inf')
        best_model_state = None
        epochs_no_improve = 0

        for ep in range(1, self.epoch + 1):
            self.model.train()
            for x_batch, onehot, y_batch in train_loader:
                x_batch, onehot, y_batch = x_batch.to(self.device), onehot.to(self.device), y_batch.to(self.device)

                self.optimizer.zero_grad()
                outputs = self.model(x_batch, onehot)
                loss = self.cri2(outputs, y_batch)
                loss.backward()
                self.optimizer.step()

            self.scheduler.step()

            avg_train_loss = self.evaluate(train_loader)
            test_loss = self.evaluate(test_loader) if test_loader else None
            val_loss = self.evaluate(val_loader) if val_loader else None

            self.train_loss.append(avg_train_loss)
            self.test_loss.append(test_loss)
            self.val_loss.append(val_loss)

            if val_loader:
                if val_loss < best_val_loss - 1e-4:
                    best_val_loss = val_loss
                    best_model_state = self.model.state_dict()
                    epochs_no_improve = 0
                else:
                    epochs_no_improve += 1
                    if epochs_no_improve >= self.patience:
                        print(f"Early stopping at epoch {ep}")
                        break

        if best_model_state:
            self.model.load_state_dict(best_model_state)

    def evaluate(self, data_loader):
        if data_loader is None:
            return None
        self.model.eval()
        total_loss = 0
        with torch.no_grad():
            for x_batch, onehot, y_batch in data_loader:
                x_batch, onehot, y_batch = x_batch.to(self.device), onehot.to(self.device), y_batch.to(self.device)
                outputs = self.model(x_batch, onehot)
                loss = self.cri2(outputs, y_batch)
                total_loss += loss.item()
        return total_loss / len(data_loader)

    def predict(self, x, onehot):
        self.model.eval()
        with torch.no_grad():
            x = x.to(self.device)
            onehot = onehot.to(self.device)
            return self.model(x, onehot)

# %%
def plot_results(model, info, train_loader, val_loader, test_loader, plot = True):
    rs, c1, c2, k1, k2, out, hid, layer, lr = info
    
    y_true_train = []
    y_pred_train = []
    
    y_true_val = []
    y_pred_val = []
    
    y_true_test = []
    y_pred_test = []

    y_true_test_M = []
    y_pred_test_M = []

    y_true_test_D = []
    y_pred_test_D = []

    y_true_test_H = []
    y_pred_test_H = []
    
    for x_batch, onehot, y_batch in train_loader:
        preds = trainer.predict(x_batch, onehot)
        y_true_train.append(y_batch)
        y_pred_train.append(preds.cpu())
    
    for x_batch, onehot, y_batch in val_loader:
        preds = trainer.predict(x_batch, onehot)
        y_true_val.append(y_batch)
        y_pred_val.append(preds.cpu())
    
    for x_batch, onehot, y_batch in test_loader:
        preds = trainer.predict(x_batch, onehot)
        y_true_test.append(y_batch)
        y_pred_test.append(preds.cpu())
    
        onehot_np = onehot.cpu().numpy()
        y_true_np = y_batch.cpu().numpy()
        y_pred_np = preds.cpu().numpy()
    
        for i in range(len(onehot_np)):
            if np.array_equal(onehot_np[i], [1, 0, 0]):  # 'M'
                y_true_test_M.append(y_true_np[i])
                y_pred_test_M.append(y_pred_np[i])
            elif np.array_equal(onehot_np[i], [0, 1, 0]):  # 'D'
                y_true_test_D.append(y_true_np[i])
                y_pred_test_D.append(y_pred_np[i])
            elif np.array_equal(onehot_np[i], [0, 0, 1]):  # 'H'
                y_true_test_H.append(y_true_np[i])
                y_pred_test_H.append(y_pred_np[i])

    y_true_train = torch.cat(y_true_train).numpy()
    y_pred_train = torch.cat(y_pred_train).numpy()
    
    y_true_val = torch.cat(y_true_val).numpy()
    y_pred_val = torch.cat(y_pred_val).numpy()
    
    y_true_test = torch.cat(y_true_test).numpy()
    y_pred_test = torch.cat(y_pred_test).numpy()

    y_true_test_M = np.array(y_true_test_M)
    y_pred_test_M = np.array(y_pred_test_M)
    
    y_true_test_D = np.array(y_true_test_D)
    y_pred_test_D = np.array(y_pred_test_D)
    
    y_true_test_H = np.array(y_true_test_H)
    y_pred_test_H = np.array(y_pred_test_H)
    
    mape_M = mean_absolute_percentage_error(y_true_test_M, y_pred_test_M) * 100 if len(y_true_test_M) > 0 else np.nan
    mape_D = mean_absolute_percentage_error(y_true_test_D, y_pred_test_D) * 100 if len(y_true_test_D) > 0 else np.nan
    mape_H = mean_absolute_percentage_error(y_true_test_H, y_pred_test_H) * 100 if len(y_true_test_H) > 0 else np.nan
    
    train_mape = mean_absolute_percentage_error(y_true_train, y_pred_train) * 100
    val_mape = mean_absolute_percentage_error(y_true_val, y_pred_val) * 100
    test_mape = mean_absolute_percentage_error(y_true_test, y_pred_test) * 100
    print(f"Model: {model}, rs: {rs}, c1: {c1}, c2: {c2}, k1: {k1}, k2: {k2}, out: {out}, hid: {hid}, layer: {layer}, lr: {lr}\n Train MAPE: {train_mape:.2f}%, Val MAPE: {val_mape:.2f}%, Test MAPE: {test_mape:.2f}%")
    print(f"Test MAPE by 'Next': M: {mape_M:.2f}%, D: {mape_D:.2f}%, H: {mape_H:.2f}%")
    
    if plot == True:
        _ = plt.figure()
        _ = plt.scatter(y_true_train, y_pred_train, label = 'Train')
        _ = plt.scatter(y_true_val, y_pred_val, label = 'Val')
        _ = plt.scatter(y_true_test, y_pred_test, label = 'Test')
        min_val = min(y_true_train.min(), y_true_test.min())
        max_val = max(y_true_train.max(), y_true_test.max())
        _ = plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Ideal line')
        _ = plt.xlabel('True SOH')
        _ = plt.ylabel('Predicted SOH')
        _ = plt.legend()
        _ = plt.title(f'Random state: {rs}, hid: {hid}, {nl} layer, lr: {lr}')
    return train_mape, val_mape, test_mape, mape_M, mape_D, mape_H

def plot_loss(info, train_loss, val_loss, test_loss):
    rs, c1, c2, k1, k2 = info
    _ = plt.figure()
    _ = plt.plot(train_loss, label = 'Train loss')
    _ = plt.plot(val_loss, label = 'Val loss')
    _ = plt.plot(test_loss, label = 'Test loss')
    _ = plt.ylim([0, 2])
    _ = plt.xlabel('Epoch')
    _ = plt.ylabel('Loss')
    _ = plt.legend()
    _ = plt.title(f'Random state: {rs}, hid: {hid}, {nl} layers, lr: {lr}')

# %% [markdown]
# ## 1. 1D CNN

# %%
class CNN1D_Compressor(nn.Module):
    def __init__(self, 
                 output_dim=4,
                 conv1_channels=16,
                 conv2_channels=16,
                 k1=3,
                 k2=3):
        super().__init__()

        self.feature_extractor = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=conv1_channels, kernel_size=k1, padding='same'),
            nn.ReLU(),
            nn.Conv1d(conv1_channels, conv2_channels, kernel_size=k2, padding='same'),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )
        self.fc = nn.Linear(conv2_channels, output_dim)

    def forward(self, x):
        if x.dim() == 2:
            x = x.unsqueeze(1)
        elif x.dim() == 3:
            if x.size(1) == 4 and x.size(2) == 1:
                x = x.transpose(1, 2)
        else:
            raise ValueError(f"Unexpected input shape: {x.shape}")

        x = self.feature_extractor(x)
        x = x.squeeze(-1)
        return self.fc(x)

# %%
class CNN1D_MLP(nn.Module):
    def __init__(self, conv1_channels, conv2_channels, kernel_size1, kernel_size2, out_dim=4, hidden_dim=64, num_layers=2, next_dim = 3):
        super(CNN1D_MLP, self).__init__()
        self.encoder = CNN1D_Compressor(out_dim, conv1_channels, conv2_channels, kernel_size1, kernel_size2)
        
        layers = []

        input_dim = out_dim + next_dim
        output_dim = 1

        layers.append(nn.Linear(input_dim, hidden_dim))
        layers.append(nn.ReLU())

        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(nn.ReLU())


        layers.append(nn.Linear(hidden_dim, output_dim))

        self.model = nn.Sequential(*layers)

    def forward(self, x, onehot):
        x_feat = self.encoder(x)
        x_concat = torch.cat([x_feat, onehot], dim=1)
        return self.model(x_concat)

class MAPELoss(nn.Module):
    def __init__(self, epsilon=1e-7):
        super(MAPELoss, self).__init__()
        self.epsilon = epsilon

    def forward(self, y_pred, y_true):
        return torch.mean(torch.abs((y_true - y_pred) / (y_true + self.epsilon))) * 100

# %% [markdown]
# ## Test

# %%
random_states = [100, 120, 140, 160, 180]
bs = 12
ep = 1000

conv1_channels = [8, 16]
conv2_channels = [8, 16]
kernel_size1 = [2, 3]
kernel_size2 = [2, 3]
cnn_outs = [2, 4, 8]

fc_hids = [4, 8, 16]
fc_layers = [1, 2, 3]
lrs = [1e-2, 1e-3]

results_df = pd.DataFrame(columns = ['rs', 'c1', 'c2', 'k1', 'k2', 'out', 'hid', 'layer', 'lr', 'Train MAPE', 'Val MAPE', 'Test MAPE', 'Next M MAPE', 'Next D MAPE', 'Next H MAPE'])

X, Y = Get_Data(dat)

y = Y['Next_SOH']

for rs, c1, c2, k1, k2, out, hid, layer, lr in product(random_states, conv1_channels, conv2_channels, kernel_size1, kernel_size2, cnn_outs, fc_hids, fc_layers, lrs):
    setRandomSeed(rs)
    start = time.time()
    X_tn, X_te, y_tn, y_te = Even_Split(X, y, 1/3, rs)
    train_loader, val_loader, test_loader, X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor, X_test_tensor, y_test_tensor, scaler = convert_to_tensor(X_tn, X_te, y_tn, y_te, bs, 1/6, rs)  

    model = CNN1D_MLP(c1, c2, k1, k2, out, hid, layer)
    trainer = Trainer(model, lr=lr, epoch = ep, random_seed = rs)
    
    trainer.train(train_loader, val_loader, test_loader)

    info = [rs, c1, c2, k1, k2, out, hid, layer, lr]
    results = plot_results("1D CNN", info, train_loader, val_loader, test_loader, plot = False)

    temp_df = pd.DataFrame(info+list(results)).T
    temp_df.columns = ['rs', 'c1', 'c2', 'k1', 'k2', 'out', 'hid', 'layer', 'lr', 'Train MAPE', 'Val MAPE', 'Test MAPE', 'Next M MAPE', 'Next D MAPE', 'Next H MAPE']
    results_df = pd.concat([results_df, temp_df])
    print(f"{time.time()-start:.2f} s")
# Out:
# Early stopping at epoch 119
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 0.95%, Val MAPE: 0.87%, Test MAPE: 0.97%
# Test MAPE by 'Next': M: 0.92%, D: 0.99%, H: 0.99%
# 7.60 s
# Early stopping at epoch 143
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.82%, Val MAPE: 0.84%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.92%, D: 1.00%, H: 0.79%
# 9.08 s
# Early stopping at epoch 147
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 0.99%, Val MAPE: 0.93%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.05%, D: 0.95%, H: 0.98%
# 9.66 s
# Early stopping at epoch 301
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.73%, Val MAPE: 0.87%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.08%, D: 0.79%, H: 0.91%
# 18.91 s
# Early stopping at epoch 80
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.85%, Val MAPE: 2.06%, Test MAPE: 1.94%
# Test MAPE by 'Next': M: 2.09%, D: 1.93%, H: 1.80%
# 5.09 s
# Early stopping at epoch 90
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.44%, Val MAPE: 1.49%, Test MAPE: 1.41%
# Test MAPE by 'Next': M: 1.25%, D: 1.81%, H: 1.16%
# 6.31 s
# Early stopping at epoch 149
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 0.84%, Val MAPE: 0.69%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 1.01%, D: 0.83%, H: 0.75%
# 9.11 s
# Early stopping at epoch 470
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.88%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.05%, D: 0.78%, H: 1.02%
# 29.98 s
# Early stopping at epoch 94
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 0.92%, Val MAPE: 0.78%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 0.92%, D: 1.05%, H: 0.82%
# 6.28 s
# Early stopping at epoch 169
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.74%, Val MAPE: 0.77%, Test MAPE: 0.83%
# Test MAPE by 'Next': M: 0.93%, D: 0.80%, H: 0.75%
# 10.98 s
# Early stopping at epoch 83
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 0.80%, Val MAPE: 0.75%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.97%, D: 0.91%, H: 0.82%
# 5.45 s
# Early stopping at epoch 94
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 1.24%, Val MAPE: 1.45%, Test MAPE: 1.20%
# Test MAPE by 'Next': M: 1.15%, D: 1.23%, H: 1.20%
# 5.99 s
# Early stopping at epoch 124
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 1.44%, Val MAPE: 1.44%, Test MAPE: 1.63%
# Test MAPE by 'Next': M: 2.06%, D: 1.28%, H: 1.54%
# 7.69 s
# Early stopping at epoch 327
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.89%, Val MAPE: 1.39%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.02%, D: 1.00%, H: 0.80%
# 20.07 s
# Early stopping at epoch 134
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.80%, Val MAPE: 0.86%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 0.95%, D: 0.79%, H: 1.02%
# 9.72 s
# Early stopping at epoch 252
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.88%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.97%, D: 0.76%, H: 0.84%
# 17.42 s
# Early stopping at epoch 103
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 1.54%, Val MAPE: 1.54%, Test MAPE: 1.65%
# Test MAPE by 'Next': M: 1.70%, D: 1.30%, H: 1.94%
# 7.12 s
# Early stopping at epoch 139
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 2, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 1.16%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.94%, D: 0.83%, H: 0.83%
# 9.75 s
# Early stopping at epoch 111
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 0.78%, Val MAPE: 0.83%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.97%, D: 0.78%, H: 0.86%
# 6.75 s
# Early stopping at epoch 216
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.73%, Val MAPE: 0.93%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.03%, D: 0.88%, H: 0.89%
# 13.21 s
# Early stopping at epoch 166
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 1.06%, Val MAPE: 0.90%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 0.96%, D: 1.15%, H: 1.05%
# 10.86 s
# Early stopping at epoch 251
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.96%, Val MAPE: 1.05%, Test MAPE: 1.07%
# Test MAPE by 'Next': M: 1.21%, D: 0.88%, H: 1.13%
# 16.66 s
# Early stopping at epoch 81
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 2.10%, Val MAPE: 2.29%, Test MAPE: 2.16%
# Test MAPE by 'Next': M: 2.35%, D: 2.15%, H: 1.96%
# 5.49 s
# Early stopping at epoch 185
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 0.74%, Val MAPE: 0.77%, Test MAPE: 0.83%
# Test MAPE by 'Next': M: 0.93%, D: 0.75%, H: 0.82%
# 12.87 s
# Early stopping at epoch 133
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.13%, Val MAPE: 1.18%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 0.90%, D: 1.16%, H: 1.27%
# 8.15 s
# Early stopping at epoch 233
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 0.94%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.11%, D: 0.78%, H: 0.86%
# 15.05 s
# Early stopping at epoch 119
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 1.13%, Val MAPE: 1.02%, Test MAPE: 1.20%
# Test MAPE by 'Next': M: 1.40%, D: 1.19%, H: 1.02%
# 7.94 s
# Early stopping at epoch 221
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.71%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.98%, D: 0.90%, H: 0.79%
# 15.46 s
# Early stopping at epoch 121
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 1.17%, Val MAPE: 1.17%, Test MAPE: 1.33%
# Test MAPE by 'Next': M: 1.52%, D: 1.03%, H: 1.44%
# 8.76 s
# Early stopping at epoch 232
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.95%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.13%, D: 0.81%, H: 1.18%
# 16.33 s
# Early stopping at epoch 79
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 0.95%, Val MAPE: 0.93%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 0.96%, D: 1.29%, H: 0.76%
# 5.08 s
# Early stopping at epoch 173
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.75%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.09%, D: 0.82%, H: 0.84%
# 10.85 s
# Early stopping at epoch 148
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.80%, Val MAPE: 0.74%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.96%, D: 0.91%, H: 0.81%
# 9.49 s
# Early stopping at epoch 135
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.97%, Val MAPE: 0.97%, Test MAPE: 1.13%
# Test MAPE by 'Next': M: 1.34%, D: 0.77%, H: 1.29%
# 8.88 s
# Early stopping at epoch 118
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 0.98%, Val MAPE: 1.07%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.22%, D: 1.03%, H: 0.92%
# 8.18 s
# Early stopping at epoch 126
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 4, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.74%, Val MAPE: 0.83%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.96%, D: 0.83%, H: 0.80%
# 8.44 s
# Early stopping at epoch 202
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 1.24%, Val MAPE: 1.22%, Test MAPE: 1.19%
# Test MAPE by 'Next': M: 1.09%, D: 1.25%, H: 1.23%
# 12.33 s
# Early stopping at epoch 181
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.90%, Val MAPE: 0.94%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.03%, D: 0.84%, H: 0.92%
# 11.07 s
# Early stopping at epoch 165
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 0.97%, Val MAPE: 1.02%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 0.97%, D: 1.14%, H: 0.89%
# 10.89 s
# Early stopping at epoch 275
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 0.86%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.95%, D: 0.89%, H: 0.79%
# 17.29 s
# Early stopping at epoch 88
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.96%, Val MAPE: 1.93%, Test MAPE: 1.88%
# Test MAPE by 'Next': M: 1.94%, D: 1.81%, H: 1.88%
# 6.05 s
# Early stopping at epoch 177
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 12.44 s
# Early stopping at epoch 114
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 0.86%, Val MAPE: 0.80%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.05%, D: 0.86%, H: 0.88%
# 6.71 s
# Early stopping at epoch 217
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.77%, Val MAPE: 1.30%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 0.95%, D: 0.99%, H: 0.82%
# 14.02 s
# Early stopping at epoch 104
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 1.03%, Val MAPE: 1.18%, Test MAPE: 1.20%
# Test MAPE by 'Next': M: 1.11%, D: 1.00%, H: 1.49%
# 7.09 s
# Early stopping at epoch 311
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.73%, Val MAPE: 0.91%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.09%, D: 0.79%, H: 0.92%
# 20.98 s
# Early stopping at epoch 89
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 1.42%, Val MAPE: 1.43%, Test MAPE: 1.39%
# Test MAPE by 'Next': M: 1.25%, D: 1.58%, H: 1.33%
# 6.52 s
# Early stopping at epoch 285
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 0.75%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.95%, D: 0.85%, H: 0.76%
# 19.67 s
# Early stopping at epoch 149
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 0.97%, Val MAPE: 0.88%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.00%, D: 0.82%, H: 1.03%
# 8.93 s
# Early stopping at epoch 118
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 1.20%, Val MAPE: 1.28%, Test MAPE: 1.42%
# Test MAPE by 'Next': M: 1.65%, D: 1.12%, H: 1.50%
# 7.94 s
# Early stopping at epoch 142
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.97%, Val MAPE: 0.94%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.10%, D: 0.96%, H: 0.92%
# 10.17 s
# Early stopping at epoch 203
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 1.12%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.14%, D: 0.87%, H: 0.79%
# 14.19 s
# Early stopping at epoch 119
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 0.78%, Val MAPE: 0.86%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 1.02%, D: 0.83%, H: 0.86%
# 8.37 s
# Early stopping at epoch 153
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 2, out: 8, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.80%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 1.00%, D: 0.76%, H: 0.87%
# 10.39 s
# Early stopping at epoch 74
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 1.11%, Val MAPE: 1.20%, Test MAPE: 1.28%
# Test MAPE by 'Next': M: 1.37%, D: 0.81%, H: 1.67%
# 4.44 s
# Early stopping at epoch 257
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.95%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.96%, D: 0.75%, H: 0.88%
# 15.25 s
# Early stopping at epoch 80
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 0.78%, Val MAPE: 0.82%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.98%, D: 0.94%, H: 0.79%
# 5.05 s
# Early stopping at epoch 170
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 1.02%, Val MAPE: 1.11%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 0.93%, D: 1.12%, H: 0.74%
# 10.56 s
# Early stopping at epoch 65
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.82%, Val MAPE: 1.88%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.94%, D: 1.79%, H: 1.72%
# 4.36 s
# Early stopping at epoch 156
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.91%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.97%, D: 1.80%, H: 1.73%
# 10.70 s
# Early stopping at epoch 162
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.25%, Val MAPE: 1.17%, Test MAPE: 1.36%
# Test MAPE by 'Next': M: 1.55%, D: 1.47%, H: 1.05%
# 9.18 s
# Early stopping at epoch 205
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.98%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.08%, D: 0.80%, H: 0.91%
# 12.91 s
# Early stopping at epoch 145
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 0.78%, Test MAPE: 0.82%
# Test MAPE by 'Next': M: 0.91%, D: 0.81%, H: 0.74%
# 9.82 s
# Early stopping at epoch 281
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.82%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.17%, D: 0.85%, H: 0.96%
# 19.16 s
# Early stopping at epoch 150
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 0.87%, Test MAPE: 0.98%
# Test MAPE by 'Next': M: 1.25%, D: 0.83%, H: 0.84%
# 10.81 s
# Early stopping at epoch 210
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 0.86%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.92%, D: 0.94%, H: 0.77%
# 14.96 s
# Early stopping at epoch 99
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 1.45%, Val MAPE: 1.35%, Test MAPE: 1.60%
# Test MAPE by 'Next': M: 2.27%, D: 0.99%, H: 1.52%
# 6.21 s
# Early stopping at epoch 133
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.77%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.18%, D: 0.84%, H: 0.84%
# 8.20 s
# Early stopping at epoch 105
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 1.11%, Val MAPE: 1.17%, Test MAPE: 1.15%
# Test MAPE by 'Next': M: 1.02%, D: 1.51%, H: 0.91%
# 6.64 s
# Early stopping at epoch 317
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.71%, Val MAPE: 0.76%, Test MAPE: 0.83%
# Test MAPE by 'Next': M: 0.98%, D: 0.79%, H: 0.73%
# 19.39 s
# Early stopping at epoch 168
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 1.12%, Val MAPE: 1.11%, Test MAPE: 1.07%
# Test MAPE by 'Next': M: 1.12%, D: 1.21%, H: 0.88%
# 11.28 s
# Early stopping at epoch 141
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 2, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.96%, Val MAPE: 1.01%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.23%, D: 0.98%, H: 1.14%
# 9.57 s
# Early stopping at epoch 66
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 0.88%, Val MAPE: 0.88%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.05%, D: 1.06%, H: 0.78%
# 4.07 s
# Early stopping at epoch 151
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.86%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.18%, D: 0.79%, H: 1.14%
# 9.25 s
# Early stopping at epoch 190
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 1.28%, Val MAPE: 1.24%, Test MAPE: 1.39%
# Test MAPE by 'Next': M: 1.37%, D: 1.30%, H: 1.49%
# 11.88 s
# Early stopping at epoch 382
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.71%, Val MAPE: 0.95%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 1.05%, D: 0.79%, H: 0.85%
# 24.15 s
# Early stopping at epoch 129
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 0.84%, Val MAPE: 0.90%, Test MAPE: 0.99%
# Test MAPE by 'Next': M: 1.12%, D: 0.86%, H: 0.99%
# 8.81 s
# Early stopping at epoch 167
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.81%, Test MAPE: 0.98%
# Test MAPE by 'Next': M: 1.12%, D: 0.81%, H: 1.02%
# 12.28 s
# Early stopping at epoch 116
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.00%, Val MAPE: 1.01%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 0.86%, D: 0.98%, H: 1.28%
# 6.80 s
# Early stopping at epoch 151
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.77%, Val MAPE: 0.75%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.23%, D: 0.79%, H: 0.87%
# 9.05 s
# Early stopping at epoch 134
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 0.76%, Val MAPE: 0.87%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.96%, D: 0.98%, H: 0.78%
# 8.59 s
# Early stopping at epoch 201
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.73%, Val MAPE: 0.87%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 1.01%, D: 0.88%, H: 0.77%
# 13.27 s
# Early stopping at epoch 65
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 2.06%, Val MAPE: 2.22%, Test MAPE: 2.11%
# Test MAPE by 'Next': M: 2.27%, D: 2.06%, H: 2.00%
# 4.48 s
# Early stopping at epoch 295
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.86%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.08%, D: 0.83%, H: 0.93%
# 22.31 s
# Early stopping at epoch 129
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 1.06%, Val MAPE: 1.07%, Test MAPE: 1.25%
# Test MAPE by 'Next': M: 1.31%, D: 0.99%, H: 1.44%
# 8.67 s
# Early stopping at epoch 280
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.89%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 0.97%, D: 1.03%, H: 0.76%
# 18.95 s
# Early stopping at epoch 111
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.85%, Val MAPE: 0.92%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.25%, D: 0.74%, H: 1.03%
# 7.87 s
# Early stopping at epoch 213
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.91%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 0.98%, D: 0.96%, H: 0.86%
# 14.45 s
# Early stopping at epoch 137
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 1.00%, Val MAPE: 1.07%, Test MAPE: 1.17%
# Test MAPE by 'Next': M: 1.33%, D: 1.01%, H: 1.18%
# 9.94 s
# Early stopping at epoch 117
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 4, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.92%, Val MAPE: 0.94%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 0.97%, D: 1.03%, H: 0.78%
# 7.65 s
# Early stopping at epoch 125
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 1.12%, Val MAPE: 1.21%, Test MAPE: 1.28%
# Test MAPE by 'Next': M: 1.32%, D: 1.04%, H: 1.47%
# 7.83 s
# Early stopping at epoch 204
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.71%, Val MAPE: 0.77%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.13%, D: 0.80%, H: 1.08%
# 12.23 s
# Early stopping at epoch 63
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 1.88%, Val MAPE: 1.88%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.93%, D: 1.77%, H: 1.78%
# 4.05 s
# Early stopping at epoch 149
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 0.80%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.94%, D: 0.82%, H: 0.82%
# 9.06 s
# Early stopping at epoch 87
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.84%, Val MAPE: 1.86%, Test MAPE: 1.81%
# Test MAPE by 'Next': M: 1.93%, D: 1.78%, H: 1.74%
# 5.75 s
# Early stopping at epoch 234
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 16.28 s
# Early stopping at epoch 94
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.34%, Val MAPE: 1.32%, Test MAPE: 1.48%
# Test MAPE by 'Next': M: 1.67%, D: 1.26%, H: 1.52%
# 5.98 s
# Early stopping at epoch 252
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.70%, Val MAPE: 0.80%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 1.03%, D: 0.78%, H: 0.88%
# 15.92 s
# Early stopping at epoch 62
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 1.87%, Val MAPE: 1.87%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.93%, D: 1.77%, H: 1.76%
# 4.24 s
# Early stopping at epoch 134
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.91%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.97%, D: 1.80%, H: 1.73%
# 9.06 s
# Early stopping at epoch 142
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 0.85%, Val MAPE: 0.79%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.08%, D: 0.97%, H: 0.84%
# 10.20 s
# Early stopping at epoch 210
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.73%, Val MAPE: 0.70%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.11%, D: 0.77%, H: 0.86%
# 14.62 s
# Early stopping at epoch 114
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 0.82%, Val MAPE: 0.85%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.01%, D: 1.02%, H: 0.84%
# 6.98 s
# Early stopping at epoch 257
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.78%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.09%, D: 0.82%, H: 0.87%
# 15.28 s
# Early stopping at epoch 79
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 0.80%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.99%, D: 0.82%, H: 0.88%
# 4.94 s
# Early stopping at epoch 190
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.76%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.04%, D: 0.87%, H: 0.82%
# 11.17 s
# Early stopping at epoch 65
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 1.69%, Val MAPE: 1.63%, Test MAPE: 1.80%
# Test MAPE by 'Next': M: 1.87%, D: 1.52%, H: 2.01%
# 4.44 s
# Early stopping at epoch 262
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 2, k2: 3, out: 8, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 0.89%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.00%, D: 0.78%, H: 0.98%
# 17.27 s
# Early stopping at epoch 143
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 0.90%, Val MAPE: 0.85%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.17%, D: 0.87%, H: 1.00%
# 8.79 s
# Early stopping at epoch 352
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.74%, Val MAPE: 0.83%, Test MAPE: 0.81%
# Test MAPE by 'Next': M: 0.89%, D: 0.80%, H: 0.74%
# 21.20 s
# Early stopping at epoch 125
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 0.85%, Val MAPE: 0.83%, Test MAPE: 0.97%
# Test MAPE by 'Next': M: 1.01%, D: 0.84%, H: 1.07%
# 8.12 s
# Early stopping at epoch 107
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.88%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.95%, D: 1.79%, H: 1.73%
# 6.80 s
# Early stopping at epoch 103
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.87%, Val MAPE: 1.87%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.93%, D: 1.77%, H: 1.76%
# 6.56 s
# Early stopping at epoch 99
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 6.85 s
# Early stopping at epoch 99
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 0.83%, Val MAPE: 0.69%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 1.06%, D: 0.83%, H: 0.81%
# 6.09 s
# Early stopping at epoch 174
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.98%, Val MAPE: 1.08%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 0.98%, D: 1.06%, H: 0.80%
# 10.70 s
# Early stopping at epoch 153
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 0.87%, Val MAPE: 0.81%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.06%, D: 0.92%, H: 0.86%
# 9.90 s
# Early stopping at epoch 334
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.80%, Test MAPE: 0.83%
# Test MAPE by 'Next': M: 0.98%, D: 0.83%, H: 0.69%
# 21.36 s
# Early stopping at epoch 68
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 1.98%, Val MAPE: 1.93%, Test MAPE: 1.98%
# Test MAPE by 'Next': M: 1.73%, D: 1.74%, H: 2.46%
# 4.72 s
# Early stopping at epoch 174
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.87%, Val MAPE: 1.06%, Test MAPE: 0.98%
# Test MAPE by 'Next': M: 1.05%, D: 0.94%, H: 0.95%
# 11.95 s
# Early stopping at epoch 115
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 0.92%, Val MAPE: 0.74%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.90%, D: 0.99%, H: 0.76%
# 7.02 s
# Early stopping at epoch 164
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.78%, Val MAPE: 0.78%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.21%, D: 0.79%, H: 1.01%
# 9.99 s
# Early stopping at epoch 107
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.74%, Val MAPE: 0.77%, Test MAPE: 0.82%
# Test MAPE by 'Next': M: 0.95%, D: 0.78%, H: 0.74%
# 6.89 s
# Early stopping at epoch 102
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.86%, Val MAPE: 0.88%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.93%, D: 1.01%, H: 0.80%
# 6.61 s
# Early stopping at epoch 61
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 1.83%, Val MAPE: 1.99%, Test MAPE: 1.85%
# Test MAPE by 'Next': M: 1.94%, D: 1.94%, H: 1.67%
# 4.39 s
# Early stopping at epoch 112
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 2, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.82%, Val MAPE: 0.86%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 1.14%, D: 0.78%, H: 0.92%
# 7.68 s
# Early stopping at epoch 127
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 1.40%, Val MAPE: 1.28%, Test MAPE: 1.49%
# Test MAPE by 'Next': M: 1.64%, D: 1.17%, H: 1.65%
# 7.71 s
# Early stopping at epoch 193
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.74%, Val MAPE: 0.78%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 1.07%, D: 0.79%, H: 0.81%
# 11.60 s
# Early stopping at epoch 199
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 0.96%, Val MAPE: 0.86%, Test MAPE: 1.09%
# Test MAPE by 'Next': M: 1.02%, D: 0.88%, H: 1.37%
# 12.85 s
# Early stopping at epoch 173
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.84%, Val MAPE: 0.85%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 0.95%, D: 0.81%, H: 1.34%
# 11.32 s
# Early stopping at epoch 63
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 2.00%, Val MAPE: 1.97%, Test MAPE: 1.91%
# Test MAPE by 'Next': M: 1.96%, D: 1.84%, H: 1.94%
# 4.51 s
# Early stopping at epoch 243
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.97%, D: 1.80%, H: 1.73%
# 16.56 s
# Early stopping at epoch 131
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.93%, Val MAPE: 1.83%, Test MAPE: 2.14%
# Test MAPE by 'Next': M: 1.72%, D: 2.76%, H: 1.94%
# 7.88 s
# Early stopping at epoch 166
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 1.01%, Val MAPE: 1.24%, Test MAPE: 1.20%
# Test MAPE by 'Next': M: 1.21%, D: 1.29%, H: 1.10%
# 10.04 s
# Early stopping at epoch 81
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 0.88%, Val MAPE: 0.96%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.09%, D: 0.89%, H: 0.89%
# 5.32 s
# Early stopping at epoch 175
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.78%, Val MAPE: 0.73%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 1.07%, D: 0.89%, H: 0.75%
# 11.30 s
# Early stopping at epoch 78
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 0.81%, Val MAPE: 0.77%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 1.08%, D: 0.79%, H: 0.89%
# 5.58 s
# Early stopping at epoch 115
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.82%, Val MAPE: 0.86%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.04%, D: 0.79%, H: 1.06%
# 7.95 s
# Early stopping at epoch 235
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 1.42%, Val MAPE: 1.33%, Test MAPE: 1.53%
# Test MAPE by 'Next': M: 1.17%, D: 1.66%, H: 1.76%
# 14.12 s
# Early stopping at epoch 98
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.77%, Val MAPE: 0.80%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.90%, D: 0.89%, H: 0.82%
# 5.93 s
# Early stopping at epoch 102
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 1.12%, Val MAPE: 1.12%, Test MAPE: 1.10%
# Test MAPE by 'Next': M: 1.20%, D: 0.90%, H: 1.18%
# 6.84 s
# Early stopping at epoch 206
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 0.85%, Test MAPE: 0.84%
# Test MAPE by 'Next': M: 0.95%, D: 0.82%, H: 0.73%
# 13.28 s
# Early stopping at epoch 123
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 0.86%, Val MAPE: 1.03%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.04%, D: 0.93%, H: 0.83%
# 8.42 s
# Early stopping at epoch 85
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 4, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.93%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.95%, D: 0.86%, H: 0.76%
# 5.85 s
# Early stopping at epoch 97
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 0.94%, Val MAPE: 0.96%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.05%, D: 1.03%, H: 0.79%
# 5.90 s
# Early stopping at epoch 135
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.83%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.11%, D: 0.81%, H: 0.97%
# 8.30 s
# Early stopping at epoch 75
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 1.84%, Val MAPE: 1.96%, Test MAPE: 1.85%
# Test MAPE by 'Next': M: 2.00%, D: 1.82%, H: 1.74%
# 4.87 s
# Early stopping at epoch 178
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.89%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 11.74 s
# Early stopping at epoch 78
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.83%, Val MAPE: 1.93%, Test MAPE: 1.84%
# Test MAPE by 'Next': M: 1.98%, D: 1.81%, H: 1.74%
# 5.35 s
# Early stopping at epoch 72
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.83%, Val MAPE: 1.93%, Test MAPE: 1.84%
# Test MAPE by 'Next': M: 1.98%, D: 1.81%, H: 1.74%
# 5.21 s
# Early stopping at epoch 142
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 0.90%, Val MAPE: 0.81%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.21%, D: 0.82%, H: 0.78%
# 8.63 s
# Early stopping at epoch 329
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.84%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.91%, D: 0.88%, H: 0.79%
# 19.75 s
# Early stopping at epoch 182
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 2.13%, Val MAPE: 1.94%, Test MAPE: 2.20%
# Test MAPE by 'Next': M: 1.70%, D: 2.32%, H: 2.58%
# 11.61 s
# Early stopping at epoch 100
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 1.04%, Val MAPE: 1.09%, Test MAPE: 1.21%
# Test MAPE by 'Next': M: 1.42%, D: 0.96%, H: 1.25%
# 6.46 s
# Early stopping at epoch 92
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 2.43%, Val MAPE: 2.39%, Test MAPE: 2.61%
# Test MAPE by 'Next': M: 2.73%, D: 2.43%, H: 2.66%
# 6.26 s
# Early stopping at epoch 216
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.77%, Val MAPE: 0.80%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.95%, D: 0.83%, H: 0.79%
# 14.85 s
# Early stopping at epoch 107
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 0.80%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.98%, D: 0.80%, H: 0.77%
# 6.49 s
# Early stopping at epoch 160
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.77%, Val MAPE: 0.70%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 1.06%, D: 0.79%, H: 0.75%
# 9.79 s
# Early stopping at epoch 151
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.97%, Val MAPE: 0.94%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 0.96%, D: 1.04%, H: 0.84%
# 9.68 s
# Early stopping at epoch 179
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.91%, Val MAPE: 0.82%, Test MAPE: 1.10%
# Test MAPE by 'Next': M: 1.38%, D: 0.83%, H: 1.09%
# 11.47 s
# Early stopping at epoch 216
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 1.05%, Val MAPE: 1.04%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.24%, D: 1.03%, H: 0.92%
# 14.82 s
# Early stopping at epoch 214
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 2, out: 8, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.76%, Val MAPE: 0.74%, Test MAPE: 0.80%
# Test MAPE by 'Next': M: 0.92%, D: 0.78%, H: 0.69%
# 14.57 s
# Early stopping at epoch 113
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 1.58%, Val MAPE: 1.54%, Test MAPE: 1.52%
# Test MAPE by 'Next': M: 1.47%, D: 1.86%, H: 1.23%
# 6.80 s
# Early stopping at epoch 156
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.95%, Val MAPE: 0.90%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 1.19%, D: 1.01%, H: 0.95%
# 9.42 s
# Early stopping at epoch 189
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 0.79%, Val MAPE: 0.89%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.94%, D: 0.78%, H: 0.85%
# 12.01 s
# Early stopping at epoch 139
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 1.35%, Val MAPE: 1.28%, Test MAPE: 1.59%
# Test MAPE by 'Next': M: 1.67%, D: 1.39%, H: 1.72%
# 8.89 s
# Early stopping at epoch 106
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 2.25%, Val MAPE: 2.13%, Test MAPE: 2.13%
# Test MAPE by 'Next': M: 2.08%, D: 2.08%, H: 2.24%
# 7.28 s
# Early stopping at epoch 478
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 0.78%, Val MAPE: 0.80%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.96%, D: 0.79%, H: 0.87%
# 31.18 s
# Early stopping at epoch 149
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.20%, Val MAPE: 1.11%, Test MAPE: 1.29%
# Test MAPE by 'Next': M: 1.37%, D: 1.28%, H: 1.24%
# 8.87 s
# Early stopping at epoch 187
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 0.82%, Test MAPE: 0.84%
# Test MAPE by 'Next': M: 0.91%, D: 0.82%, H: 0.79%
# 11.58 s
# Early stopping at epoch 92
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 1.41%, Val MAPE: 1.33%, Test MAPE: 1.29%
# Test MAPE by 'Next': M: 1.26%, D: 1.49%, H: 1.11%
# 5.86 s
# Early stopping at epoch 258
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 0.93%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.07%, D: 0.75%, H: 1.19%
# 16.44 s
# Early stopping at epoch 166
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 0.91%, Val MAPE: 0.90%, Test MAPE: 0.97%
# Test MAPE by 'Next': M: 1.00%, D: 1.02%, H: 0.89%
# 10.57 s
# Early stopping at epoch 242
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.95%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.00%, D: 0.90%, H: 0.82%
# 16.31 s
# Early stopping at epoch 91
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 1.27%, Val MAPE: 1.18%, Test MAPE: 1.38%
# Test MAPE by 'Next': M: 1.42%, D: 0.91%, H: 1.82%
# 5.64 s
# Early stopping at epoch 290
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.74%, Val MAPE: 0.79%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 1.10%, D: 0.77%, H: 0.67%
# 17.49 s
# Early stopping at epoch 196
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 1.11%, Val MAPE: 1.23%, Test MAPE: 1.23%
# Test MAPE by 'Next': M: 1.15%, D: 0.94%, H: 1.60%
# 12.45 s
# Early stopping at epoch 92
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.93%, Val MAPE: 1.18%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 0.85%, D: 0.99%, H: 0.94%
# 5.93 s
# Early stopping at epoch 177
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 0.85%, Val MAPE: 1.01%, Test MAPE: 0.98%
# Test MAPE by 'Next': M: 1.12%, D: 0.84%, H: 0.99%
# 11.98 s
# Early stopping at epoch 316
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 2, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.73%, Val MAPE: 0.79%, Test MAPE: 0.83%
# Test MAPE by 'Next': M: 1.06%, D: 0.71%, H: 0.73%
# 21.20 s
# Early stopping at epoch 136
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 0.88%, Val MAPE: 0.80%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 1.08%, D: 0.92%, H: 0.78%
# 8.26 s
# Early stopping at epoch 113
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.91%, Val MAPE: 0.86%, Test MAPE: 0.98%
# Test MAPE by 'Next': M: 1.22%, D: 0.94%, H: 0.77%
# 6.76 s
# Early stopping at epoch 88
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 1.96%, Val MAPE: 1.93%, Test MAPE: 1.88%
# Test MAPE by 'Next': M: 1.94%, D: 1.81%, H: 1.88%
# 5.67 s
# Early stopping at epoch 177
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 11.24 s
# Early stopping at epoch 143
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.82%, Val MAPE: 1.88%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.94%, D: 1.79%, H: 1.72%
# 9.64 s
# Early stopping at epoch 153
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.88%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.94%, D: 1.79%, H: 1.72%
# 10.39 s
# Early stopping at epoch 134
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.02%, Val MAPE: 1.16%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.26%, D: 0.97%, H: 0.94%
# 8.00 s
# Early stopping at epoch 356
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 0.83%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.13%, D: 1.10%, H: 0.96%
# 21.15 s
# Early stopping at epoch 125
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 1.22%, Val MAPE: 1.16%, Test MAPE: 1.30%
# Test MAPE by 'Next': M: 1.25%, D: 1.39%, H: 1.26%
# 7.99 s
# Early stopping at epoch 514
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.77%, Val MAPE: 1.18%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.10%, D: 0.93%, H: 1.00%
# 32.44 s
# Early stopping at epoch 86
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 0.91%, Val MAPE: 0.87%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.16%, D: 0.97%, H: 0.86%
# 5.91 s
# Early stopping at epoch 255
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 1.00%, Val MAPE: 1.01%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.24%, D: 0.88%, H: 1.19%
# 17.12 s
# Early stopping at epoch 381
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 1.31%, Val MAPE: 1.24%, Test MAPE: 1.51%
# Test MAPE by 'Next': M: 1.71%, D: 1.42%, H: 1.39%
# 22.73 s
# Early stopping at epoch 261
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 1.16%, Val MAPE: 1.22%, Test MAPE: 1.30%
# Test MAPE by 'Next': M: 1.39%, D: 1.37%, H: 1.14%
# 15.73 s
# Early stopping at epoch 156
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 1.71%, Val MAPE: 1.70%, Test MAPE: 1.70%
# Test MAPE by 'Next': M: 1.81%, D: 1.78%, H: 1.51%
# 10.09 s
# Early stopping at epoch 366
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.77%, Val MAPE: 0.89%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 0.88%, D: 0.93%, H: 0.78%
# 23.23 s
# Early stopping at epoch 180
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 0.85%, Val MAPE: 0.94%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 1.16%, D: 0.85%, H: 1.09%
# 12.33 s
# Early stopping at epoch 109
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 4, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.77%, Val MAPE: 0.93%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.93%, D: 0.77%, H: 0.97%
# 7.75 s
# Early stopping at epoch 94
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 0.95%, Val MAPE: 0.93%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.94%, D: 0.87%, H: 0.89%
# 5.65 s
# Early stopping at epoch 176
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.78%, Val MAPE: 0.85%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 0.99%, D: 0.79%, H: 1.03%
# 10.84 s
# Early stopping at epoch 53
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 2.12%, Val MAPE: 2.04%, Test MAPE: 2.03%
# Test MAPE by 'Next': M: 2.02%, D: 1.96%, H: 2.10%
# 3.53 s
# Early stopping at epoch 118
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 1.83%, Val MAPE: 1.87%, Test MAPE: 1.82%
# Test MAPE by 'Next': M: 1.95%, D: 1.79%, H: 1.72%
# 7.59 s
# Early stopping at epoch 58
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.96%, Val MAPE: 1.93%, Test MAPE: 1.88%
# Test MAPE by 'Next': M: 1.94%, D: 1.81%, H: 1.88%
# 4.05 s
# Early stopping at epoch 110
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.82%, Val MAPE: 1.90%, Test MAPE: 1.83%
# Test MAPE by 'Next': M: 1.96%, D: 1.80%, H: 1.73%
# 7.53 s
# Early stopping at epoch 140
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 0.87%, Val MAPE: 0.81%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 1.00%, D: 0.89%, H: 0.78%
# 8.32 s
# Early stopping at epoch 152
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.88%, Val MAPE: 0.88%, Test MAPE: 1.12%
# Test MAPE by 'Next': M: 1.25%, D: 0.92%, H: 1.21%
# 9.03 s
# Early stopping at epoch 100
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 1.12%, Val MAPE: 1.15%, Test MAPE: 1.27%
# Test MAPE by 'Next': M: 1.38%, D: 0.73%, H: 1.70%
# 6.55 s
# Early stopping at epoch 331
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.80%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.98%, D: 0.84%, H: 0.85%
# 21.30 s
# Early stopping at epoch 131
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 1.07%, Val MAPE: 1.17%, Test MAPE: 1.18%
# Test MAPE by 'Next': M: 1.12%, D: 0.87%, H: 1.55%
# 8.94 s
# Early stopping at epoch 206
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 0.89%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.94%, D: 0.87%, H: 0.87%
# 14.05 s
# Early stopping at epoch 146
# Model: 1D CNN, rs: 100, c1: 8, c2: 8, k1: 3, k2: 3, out: 8, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 1.51%, Val MAPE: 1.48%, Test MAPE: 1.68%
# Test MAPE by 'Next': M: 1.15%, D: 1.77%, H: 2.11%
# 8.91 s
# Early stopping at epoch 154
# ...
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 0.67%, Val MAPE: 0.90%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 0.94%, D: 0.96%, H: 0.87%
# 4.65 s
# Early stopping at epoch 111
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 1.15%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.94%, D: 0.82%, H: 0.86%
# 7.43 s
# Early stopping at epoch 85
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.41%, Val MAPE: 1.62%, Test MAPE: 1.36%
# Test MAPE by 'Next': M: 1.55%, D: 1.15%, H: 1.38%
# 6.07 s
# Early stopping at epoch 229
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 1.06%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 0.95%, D: 1.20%, H: 1.01%
# 16.16 s
# Early stopping at epoch 148
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.13%, Val MAPE: 1.13%, Test MAPE: 1.13%
# Test MAPE by 'Next': M: 1.46%, D: 0.81%, H: 1.10%
# 9.30 s
# Early stopping at epoch 170
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 1.00%, Test MAPE: 0.93%
# Test MAPE by 'Next': M: 0.96%, D: 1.00%, H: 0.82%
# 10.55 s
# Early stopping at epoch 102
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 1.04%, Val MAPE: 1.19%, Test MAPE: 1.25%
# Test MAPE by 'Next': M: 1.35%, D: 1.26%, H: 1.13%
# 6.83 s
# Early stopping at epoch 250
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.70%, Val MAPE: 0.91%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 0.94%, D: 0.97%, H: 0.93%
# 16.55 s
# Early stopping at epoch 178
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 1.00%, Val MAPE: 1.22%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.24%, D: 0.95%, H: 0.93%
# 12.56 s
# Early stopping at epoch 158
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.71%, Val MAPE: 0.87%, Test MAPE: 0.81%
# Test MAPE by 'Next': M: 0.87%, D: 0.80%, H: 0.74%
# 11.33 s
# Early stopping at epoch 148
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 0.93%, Val MAPE: 1.27%, Test MAPE: 1.24%
# Test MAPE by 'Next': M: 1.47%, D: 1.35%, H: 0.90%
# 9.23 s
# Early stopping at epoch 141
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.71%, Val MAPE: 0.94%, Test MAPE: 0.86%
# Test MAPE by 'Next': M: 1.06%, D: 0.81%, H: 0.71%
# 8.72 s
# Early stopping at epoch 129
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.98%, Val MAPE: 1.21%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 0.93%, D: 1.13%, H: 1.04%
# 8.59 s
# Early stopping at epoch 227
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.70%, Val MAPE: 0.95%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.91%, D: 0.84%, H: 0.87%
# 15.05 s
# Early stopping at epoch 113
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 0.94%, Val MAPE: 1.10%, Test MAPE: 1.15%
# Test MAPE by 'Next': M: 1.24%, D: 1.15%, H: 1.06%
# 8.13 s
# Early stopping at epoch 115
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 2, out: 8, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.69%, Val MAPE: 0.86%, Test MAPE: 0.94%
# Test MAPE by 'Next': M: 1.07%, D: 0.83%, H: 0.92%
# 8.28 s
# Early stopping at epoch 141
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 1.60%, Val MAPE: 1.51%, Test MAPE: 1.74%
# Test MAPE by 'Next': M: 1.70%, D: 1.82%, H: 1.71%
# 8.70 s
# Early stopping at epoch 110
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.66%, Val MAPE: 0.99%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 0.99%, D: 0.95%, H: 0.93%
# 6.77 s
# Early stopping at epoch 126
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 0.83%, Val MAPE: 1.04%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 1.16%, D: 1.01%, H: 0.94%
# 8.32 s
# Early stopping at epoch 214
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.95%, Val MAPE: 1.09%, Test MAPE: 1.23%
# Test MAPE by 'Next': M: 1.23%, D: 1.27%, H: 1.19%
# 14.10 s
# Early stopping at epoch 126
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.04%, Val MAPE: 1.09%, Test MAPE: 1.11%
# Test MAPE by 'Next': M: 1.27%, D: 0.93%, H: 1.12%
# 8.94 s
# Early stopping at epoch 159
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 0.82%, Val MAPE: 0.88%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.01%, D: 0.99%, H: 1.02%
# 11.21 s
# Early stopping at epoch 105
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.04%, Val MAPE: 1.15%, Test MAPE: 1.04%
# Test MAPE by 'Next': M: 1.05%, D: 1.30%, H: 0.78%
# 6.51 s
# Early stopping at epoch 80
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.66%, Val MAPE: 0.79%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.96%, D: 0.92%, H: 0.72%
# 5.07 s
# Early stopping at epoch 110
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 0.83%, Val MAPE: 1.06%, Test MAPE: 1.09%
# Test MAPE by 'Next': M: 1.24%, D: 0.96%, H: 1.05%
# 7.24 s
# Early stopping at epoch 246
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.78%, Val MAPE: 0.92%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 1.04%, D: 1.01%, H: 0.96%
# 16.10 s
# Early stopping at epoch 132
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 0.75%, Val MAPE: 0.87%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 0.99%, D: 1.12%, H: 0.98%
# 9.26 s
# Early stopping at epoch 120
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.81%, Val MAPE: 0.92%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 1.02%, D: 1.16%, H: 1.02%
# 8.45 s
# Early stopping at epoch 81
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 1.25%, Val MAPE: 1.37%, Test MAPE: 1.62%
# Test MAPE by 'Next': M: 1.64%, D: 1.64%, H: 1.57%
# 5.01 s
# Early stopping at epoch 115
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.90%, Val MAPE: 1.07%, Test MAPE: 1.07%
# Test MAPE by 'Next': M: 1.14%, D: 0.97%, H: 1.10%
# 7.07 s
# Early stopping at epoch 133
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 1.15%, Val MAPE: 1.33%, Test MAPE: 1.34%
# Test MAPE by 'Next': M: 1.74%, D: 1.31%, H: 0.98%
# 8.81 s
# Early stopping at epoch 75
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.69%, Val MAPE: 0.88%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.99%, D: 0.87%, H: 0.81%
# 4.99 s
# Early stopping at epoch 141
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 0.71%, Val MAPE: 0.84%, Test MAPE: 0.88%
# Test MAPE by 'Next': M: 0.99%, D: 0.83%, H: 0.82%
# 9.84 s
# Early stopping at epoch 101
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 2, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 0.92%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 0.99%, D: 1.05%, H: 1.13%
# 7.11 s
# Early stopping at epoch 112
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 0.78%, Val MAPE: 0.84%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 0.99%, D: 0.87%, H: 0.85%
# 6.89 s
# Early stopping at epoch 392
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.82%, Val MAPE: 1.10%, Test MAPE: 1.20%
# Test MAPE by 'Next': M: 1.11%, D: 1.28%, H: 1.20%
# 23.85 s
# Early stopping at epoch 86
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 0.70%, Val MAPE: 0.85%, Test MAPE: 0.85%
# Test MAPE by 'Next': M: 0.94%, D: 0.80%, H: 0.82%
# 5.77 s
# Early stopping at epoch 121
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.83%, Val MAPE: 0.99%, Test MAPE: 1.18%
# Test MAPE by 'Next': M: 1.16%, D: 1.20%, H: 1.16%
# 7.98 s
# Early stopping at epoch 112
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 0.89%, Val MAPE: 1.02%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 0.96%, D: 0.84%, H: 0.96%
# 7.83 s
# Early stopping at epoch 241
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 0.79%, Val MAPE: 0.95%, Test MAPE: 1.02%
# Test MAPE by 'Next': M: 1.08%, D: 0.94%, H: 1.03%
# 16.75 s
# Early stopping at epoch 176
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 0.71%, Val MAPE: 0.89%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 1.02%, D: 1.22%, H: 0.86%
# 10.68 s
# Early stopping at epoch 136
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.64%, Val MAPE: 0.98%, Test MAPE: 1.01%
# Test MAPE by 'Next': M: 1.02%, D: 1.05%, H: 0.96%
# 8.46 s
# Early stopping at epoch 86
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 0.84%, Val MAPE: 1.02%, Test MAPE: 0.96%
# Test MAPE by 'Next': M: 1.08%, D: 0.94%, H: 0.86%
# 5.78 s
# Early stopping at epoch 169
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.85%, Val MAPE: 1.03%, Test MAPE: 1.17%
# Test MAPE by 'Next': M: 1.24%, D: 1.22%, H: 1.06%
# 11.02 s
# Early stopping at epoch 118
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 0.77%, Val MAPE: 0.92%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.07%, D: 0.81%, H: 0.86%
# 8.29 s
# Early stopping at epoch 189
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.68%, Val MAPE: 0.85%, Test MAPE: 0.87%
# Test MAPE by 'Next': M: 0.99%, D: 0.82%, H: 0.80%
# 13.24 s
# Early stopping at epoch 62
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 2.77%, Val MAPE: 3.14%, Test MAPE: 2.68%
# Test MAPE by 'Next': M: 2.61%, D: 2.03%, H: 3.41%
# 3.86 s
# Early stopping at epoch 161
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 0.88%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 1.01%, D: 0.86%, H: 0.81%
# 9.91 s
# Early stopping at epoch 90
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.84%, Val MAPE: 1.01%, Test MAPE: 0.98%
# Test MAPE by 'Next': M: 1.22%, D: 0.91%, H: 0.80%
# 5.98 s
# Early stopping at epoch 79
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 0.85%, Test MAPE: 1.00%
# Test MAPE by 'Next': M: 0.97%, D: 1.06%, H: 0.95%
# 5.23 s
# Early stopping at epoch 84
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 0.82%, Val MAPE: 0.99%, Test MAPE: 0.91%
# Test MAPE by 'Next': M: 1.02%, D: 0.91%, H: 0.80%
# 6.05 s
# Early stopping at epoch 99
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 4, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 1.16%, Val MAPE: 1.33%, Test MAPE: 1.56%
# Test MAPE by 'Next': M: 1.36%, D: 1.83%, H: 1.48%
# 7.02 s
# Early stopping at epoch 149
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 4, layer: 1, lr: 0.01
#  Train MAPE: 0.91%, Val MAPE: 0.95%, Test MAPE: 0.97%
# Test MAPE by 'Next': M: 1.08%, D: 0.92%, H: 0.91%
# 9.12 s
# Early stopping at epoch 142
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 4, layer: 1, lr: 0.001
#  Train MAPE: 0.72%, Val MAPE: 0.91%, Test MAPE: 1.29%
# Test MAPE by 'Next': M: 0.84%, D: 1.52%, H: 1.51%
# 8.70 s
# Early stopping at epoch 94
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 4, layer: 2, lr: 0.01
#  Train MAPE: 1.07%, Val MAPE: 1.15%, Test MAPE: 1.23%
# Test MAPE by 'Next': M: 1.36%, D: 1.21%, H: 1.11%
# 6.24 s
# Early stopping at epoch 400
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 4, layer: 2, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 0.83%, Test MAPE: 1.02%
# Test MAPE by 'Next': M: 0.91%, D: 1.14%, H: 1.02%
# 26.00 s
# Early stopping at epoch 58
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 4, layer: 3, lr: 0.01
#  Train MAPE: 1.78%, Val MAPE: 1.72%, Test MAPE: 1.95%
# Test MAPE by 'Next': M: 1.99%, D: 1.73%, H: 2.12%
# 4.13 s
# Early stopping at epoch 114
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 4, layer: 3, lr: 0.001
#  Train MAPE: 1.78%, Val MAPE: 1.73%, Test MAPE: 1.94%
# Test MAPE by 'Next': M: 2.01%, D: 1.72%, H: 2.10%
# 8.02 s
# Early stopping at epoch 57
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 8, layer: 1, lr: 0.01
#  Train MAPE: 1.51%, Val MAPE: 1.52%, Test MAPE: 1.46%
# Test MAPE by 'Next': M: 1.37%, D: 1.38%, H: 1.63%
# 3.60 s
# Early stopping at epoch 90
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 8, layer: 1, lr: 0.001
#  Train MAPE: 0.67%, Val MAPE: 0.89%, Test MAPE: 0.90%
# Test MAPE by 'Next': M: 0.97%, D: 0.82%, H: 0.92%
# 5.53 s
# Early stopping at epoch 146
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 8, layer: 2, lr: 0.01
#  Train MAPE: 0.75%, Val MAPE: 0.85%, Test MAPE: 0.89%
# Test MAPE by 'Next': M: 0.89%, D: 0.88%, H: 0.89%
# 9.60 s
# Early stopping at epoch 204
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 8, layer: 2, lr: 0.001
#  Train MAPE: 0.75%, Val MAPE: 0.90%, Test MAPE: 1.03%
# Test MAPE by 'Next': M: 0.93%, D: 1.11%, H: 1.06%
# 13.36 s
# Early stopping at epoch 113
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 8, layer: 3, lr: 0.01
#  Train MAPE: 0.68%, Val MAPE: 0.91%, Test MAPE: 0.83%
# Test MAPE by 'Next': M: 0.91%, D: 0.81%, H: 0.76%
# 7.97 s
# Early stopping at epoch 597
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 8, layer: 3, lr: 0.001
#  Train MAPE: 0.69%, Val MAPE: 0.87%, Test MAPE: 0.92%
# Test MAPE by 'Next': M: 0.95%, D: 0.89%, H: 0.91%
# 41.60 s
# Early stopping at epoch 76
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 16, layer: 1, lr: 0.01
#  Train MAPE: 0.74%, Val MAPE: 0.96%, Test MAPE: 1.05%
# Test MAPE by 'Next': M: 0.94%, D: 1.29%, H: 0.93%
# 4.72 s
# Early stopping at epoch 115
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 16, layer: 1, lr: 0.001
#  Train MAPE: 1.10%, Val MAPE: 1.23%, Test MAPE: 1.41%
# Test MAPE by 'Next': M: 1.39%, D: 1.47%, H: 1.37%
# 7.11 s
# Early stopping at epoch 100
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 16, layer: 2, lr: 0.01
#  Train MAPE: 0.91%, Val MAPE: 0.99%, Test MAPE: 1.17%
# Test MAPE by 'Next': M: 1.00%, D: 1.30%, H: 1.22%
# 6.67 s
# Early stopping at epoch 246
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 16, layer: 2, lr: 0.001
#  Train MAPE: 0.63%, Val MAPE: 0.92%, Test MAPE: 0.95%
# Test MAPE by 'Next': M: 0.98%, D: 0.92%, H: 0.94%
# 16.13 s
# Early stopping at epoch 60
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 16, layer: 3, lr: 0.01
#  Train MAPE: 0.96%, Val MAPE: 1.04%, Test MAPE: 1.21%
# Test MAPE by 'Next': M: 1.16%, D: 1.35%, H: 1.11%
# 4.36 s
# Early stopping at epoch 164
# Model: 1D CNN, rs: 180, c1: 16, c2: 16, k1: 3, k2: 3, out: 8, hid: 16, layer: 3, lr: 0.001
#  Train MAPE: 0.80%, Val MAPE: 0.99%, Test MAPE: 1.06%
# Test MAPE by 'Next': M: 0.98%, D: 1.15%, H: 1.04%
# 11.65 s

# %%
summary_df = results_df.groupby(['c1', 'c2', 'k1', 'k2', 'out', 'hid', 'layer', 'lr'])[['Train MAPE', 'Val MAPE', 'Test MAPE', 'Next M MAPE', 'Next D MAPE', 'Next H MAPE']].mean().reset_index()
summary_df 
summary_df.to_csv('1D CNN_Processed_next_info_sum.csv')
results_df.to_csv('1D CNN_Processed_next_info.csv')
# Out:
#        c1    c2   k1   k2  out   hid  layer     lr  Train MAPE  Val MAPE  \
# 0     8.0   8.0  2.0  2.0  2.0   4.0    1.0  0.001    1.027310  1.045048
# 1     8.0   8.0  2.0  2.0  2.0   4.0    1.0  0.010    1.281998  1.245462
# 2     8.0   8.0  2.0  2.0  2.0   4.0    2.0  0.001    1.146607  1.231950
# 3     8.0   8.0  2.0  2.0  2.0   4.0    2.0  0.010    1.414580  1.358115
# 4     8.0   8.0  2.0  2.0  2.0   4.0    3.0  0.001    1.222115  1.266222
# ..    ...   ...  ...  ...  ...   ...    ...    ...         ...       ...
# 859  16.0  16.0  3.0  3.0  8.0  16.0    1.0  0.010    0.904730  1.031861
# 860  16.0  16.0  3.0  3.0  8.0  16.0    2.0  0.001    0.880441  0.982921
# 861  16.0  16.0  3.0  3.0  8.0  16.0    2.0  0.010    1.106881  1.211110
# 862  16.0  16.0  3.0  3.0  8.0  16.0    3.0  0.001    0.926529  1.067070
# 863  16.0  16.0  3.0  3.0  8.0  16.0    3.0  0.010    1.026521  1.117665
#
#      Test MAPE  Next M MAPE  Next D MAPE  Next H MAPE
# 0     1.055305     1.134429     1.028482     1.003003
# 1     1.277519     1.200152     1.321685     1.310719
# 2     1.170371     1.238621     1.127929     1.144565
# 3     1.436340     1.457187     1.467414     1.384419
# 4     1.278740     1.355334     1.301806     1.179080
# ..         ...          ...          ...          ...
# 859   1.008052     1.012598     1.036655     0.974903
# 860   1.018224     1.186802     0.925392     0.942478
# 861   1.203358     1.316831     1.324008     0.969235
# 862   1.038861     1.095524     0.958013     1.063047
# 863   1.116399     1.215583     1.030663     1.102951
#
# [864 rows x 14 columns]
